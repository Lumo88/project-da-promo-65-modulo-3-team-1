# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from src import soporte_correlacion as sp_corr

# %%
pd.set_option("display.max_columns",None) #display todas las columnas
df_hr = pd.read_csv("files/hr_final.csv",index_col=0)

df_hr.head()
# Out:
#   attrition    business_travel              department  distance_from_home  \
# 0       yes      travel_rarely                   sales                   1
# 1        no  travel_frequently  research & development                   8
# 2       yes      travel_rarely  research & development                   2
# 3        no  travel_frequently  research & development                   3
# 4        no      travel_rarely  research & development                   2
#
#    education education_field  employee_number  environment_satisfaction  \
# 0          2   life sciences                1                         2
# 1          1   life sciences                2                         3
# 2          2           other                4                         4
# 3          4   life sciences                5                         4
# 4          1         medical                7                         1
#
#    gender  job_involvement  job_level                 job_role marital_status  \
# 0  female                3          2         sales executive          single
# 1    male                2          2      research scientist         married
# 2    male                2          1   laboratory technician          single
# 3  female                3          1      research scientist         married
# 4    male                3          1   laboratory technician         married
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
# 2                     6       yes                   15                   3
# 3                     1       yes                   11                   3
# 4                     9        no                   12                   3
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
# 2                          2                   0                    7
# 3                          3                   0                    8
# 4                          4                   1                    6
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                         0                  1                 6
# 1                         3                  3                10
# 2                         3                  3                 0
# 3                         3                  3                 8
# 4                         3                  3                 2
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager  \
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0
# 2                      0                           0                      0.0
# 3                      7                           3                      0.0
# 4                      2                           2                      2.0
#
#    age  job_satisfaction  monthly_income
# 0   41                 4          5993.0
# 1   49                 2          5130.0
# 2   37                 3          2090.0
# 3   33                 3          2909.0
# 4   27                 2          3468.0

# %%
df_hr.columns
# Out:
# Index(['attrition', 'business_travel', 'department', 'distance_from_home',
#        'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'job_involvement', 'job_level',
#        'job_role', 'marital_status', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager', 'age',
#        'job_satisfaction', 'monthly_income'],
#       dtype='str')

# %% [markdown]
# ### **<font color="red">¿Existe una brecha salarial entre los empleados que se quedan y los que se van?</font>**
#       - Herramienta: sns.boxplot(x='attrition', y='monthly_income', data=df)

# %%
df_hr["monthly_income"].describe(include=np.number).T.reset_index()
# Out:
#    index  monthly_income
# 0  count     1474.000000
# 1   mean     6500.079376
# 2    std     4702.432869
# 3    min     1009.000000
# 4    25%     2909.500000
# 5    50%     4936.000000
# 6    75%     8379.000000
# 7    max    19999.000000

# %%
df_hr['salary_cat'] = pd.cut(df_hr['monthly_income'], bins=[0,5000,10000,20000], labels=['bajo','medio','alto'])

# %%
crosstab_salary= pd.crosstab(df_hr['salary_cat'], df_hr['attrition'], normalize= 'columns')
print(crosstab_salary)
# Out:
# attrition         no       yes
# salary_cat
# bajo        0.473301  0.689076
# medio       0.319579  0.210084
# alto        0.207120  0.100840

# %%
ax = sns.heatmap(crosstab_salary, annot=True, cmap='pink', fmt='.2f')
ax.set_yticklabels(["Bajo (0 - 5k)","Medio (5k - 10k)","Alto (10k - 20k)"], rotation=0)
plt.title('¿Existe una brecha salarial en la rotación?', fontsize=12)
plt.xlabel('Baja laboral')
plt.ylabel('Rotación')

plt.show()

# %% [markdown]
# la mayoria de los que se van son los que tienen el salario más bajo.

# %%
sns.boxplot(data=df_hr,x="attrition", y="monthly_income")
plt.title('Distribución salario según la rotación de empleados', fontsize=12)
plt.xlabel('Baja laboral')
plt.ylabel('Salario')

plt.show()

# %% [markdown]
# Existe una brecha salarial entre los empleados que se quedan y los que se van : < monthly_income = > attrition vs  >monthly_income = < attrition.
# Notamos que la mediana del salario de los que se van, es igual al 25% del salario mínimo de los que se quedan.

# %% [markdown]
# ### **<font color="red">¿El trabajo extra (Overtime) es un detonante para la rotación? </font>**
#        - Herramienta: sns.countplot(x='over_time', hue='attrition', data=df)

# %%
crosstab = pd.crosstab(df_hr['over_time'], df_hr['attrition'], normalize= 'columns')
print(crosstab)
# Out:
# attrition        no      yes
# over_time
# no         0.773463  0.47479
# yes        0.226537  0.52521

# %%
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='.0%')
plt.title('¿Las horas extras es un detonante para la rotación?', fontsize=12)
plt.xlabel('Baja laboral')
plt.ylabel('Horas Extras')

plt.show()

# %%
sns.countplot(x='over_time', hue='attrition',data=df_hr)
plt.title('¿Las horas extras es un detonante para la rotación?', fontsize=12)
plt.xlabel('Horas Extras')
plt.ylabel('Cantidad')

plt.show()

# %%
sns.histplot(x='over_time', hue='attrition', data=df_hr, 
             multiple='dodge', shrink=0.8, stat='percent')

plt.title('¿Las horas extras es un detonante para la rotación?', fontsize=12)
plt.ylabel('Porcentaje (%)')
plt.xlabel('Horas Extras')
plt.show()

# %% [markdown]
# ### **<font color="red">¿Influye la distancia al hogar en la decisión de abandonar la empresa? </font>**
#        - Herramienta: sns.kdeplot comparando distance_from_home para ambos grupos de attrition.

# %%
sns.kdeplot(data=df_hr, x="distance_from_home", hue="attrition");
#dibuja la estimación de densidad kernel de `distance_from_home` para cada valor de `attrition`, comparando la distribución de distancias entre los que se quedan y los que se van.

# %%
df_hr['distance_cat']= pd.cut(df_hr['distance_from_home'], bins=[0,10,20,30], labels=['Cerca','Medio','Lejos'])

# %%
sns.countplot(x='distance_cat', hue='attrition',data=df_hr);

# %%
crosstabDisCount = pd.crosstab(df_hr['distance_cat'], df_hr['attrition'], normalize= 'columns')

# %%
crosstabDisCount
# Out:
# attrition           no       yes
# distance_cat
# Cerca         0.715210  0.605042
# Medio         0.156149  0.201681
# Lejos         0.128641  0.193277

# %%
sns.heatmap(crosstabDisCount, annot=True, fmt='.0%',cmap='Oranges')
plt.title('¿Influye la distancia al hogar en la decisión de abandonar la empresa?', fontsize=12)
plt.xlabel('Baja laboral')
plt.ylabel('Distancia')

plt.show()

# %% [markdown]
# el 40% de los que se van, viven entre medio y lejos de la empresa

# %% [markdown]
# ### **<font color="red"> ¿Qué departamentos o roles tienen la tasa de rotación más alta?</font>**
#     - Herramienta: Gráfico de barras apiladas o sns.countplot con job_role o department.

# %%
sns.countplot(data=df_hr, x="attrition", hue="department")
# Out:
# <Axes: xlabel='attrition', ylabel='count'>

# %% [markdown]
# No hay patrón claro del porcentaje de rotación por departamento, pero podemos indicar que el 53% de los que se van pertenecen a development, un 37% en ventas. Ventas (Sales) es el punto crítico: En el grupo de los que se quedan (no), representan el 28%. En el grupo de los que se van (yes), suben al 37%. Conclusión: El departamento de Ventas tiene una rotación proporcionalmente más alta que su peso en la empresa.

# %%
df_hr['job_level_cat']= pd.cut(df_hr['job_level'], bins=[1,2,3,4,5], labels=['junior','semi-senior','senior','expert'])

# %%
pd.crosstab(df_hr['job_level_cat'], df_hr['department'], normalize= 'columns').round(2)
# Out:
# department     human resources  research & development  sales  unknown
# job_level_cat
# junior                    0.43                    0.53   0.65     0.50
# semi-senior               0.20                    0.25   0.22     0.22
# senior                    0.13                    0.12   0.09     0.28
# expert                    0.23                    0.09   0.04     0.00

# %%
pd.crosstab(df_hr['job_level_cat'], df_hr['department'], normalize= 'index').round(2)
# Out:
# department     human resources  research & development  sales  unknown
# job_level_cat
# junior                    0.02                    0.52   0.44     0.02
# semi-senior               0.03                    0.58   0.37     0.02
# senior                    0.04                    0.60   0.31     0.05
# expert                    0.10                    0.71   0.19     0.00

# %%
df_hr.groupby('attrition')['department'].value_counts(normalize=True).round(2)
# Out:
# attrition  department
# no         research & development    0.66
#            sales                     0.28
#            human resources           0.04
#            unknown                   0.02
# yes        research & development    0.53
#            sales                     0.37
#            human resources           0.05
#            unknown                   0.04
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df_hr, x="attrition", hue="job_role",)
# Out:
# <Axes: xlabel='attrition', ylabel='count'>

# %%
pd.crosstab(df_hr['job_role'], df_hr['attrition'], normalize= 'columns').round(2)
# Out:
# attrition                     no   yes
# job_role
# healthcare representative   0.10  0.04
# human resources             0.03  0.05
# laboratory technician       0.16  0.26
# manager                     0.08  0.02
# manufacturing director      0.11  0.04
# research director           0.06  0.01
# research scientist          0.20  0.20
# sales executive             0.22  0.24
# sales representative        0.04  0.14

# %%
pd.crosstab(df_hr['job_role'], df_hr['attrition'], normalize= 'index').round(2)
# Out:
# attrition                     no   yes
# job_role
# healthcare representative   0.93  0.07
# human resources             0.75  0.25
# laboratory technician       0.76  0.24
# manager                     0.95  0.05
# manufacturing director      0.93  0.07
# research director           0.98  0.02
# research scientist          0.84  0.16
# sales executive             0.83  0.17
# sales representative        0.60  0.40

# %%
# 26% labotatory technician, 20% research scientist, 24% sales executive

# %%
df_hr.groupby('attrition')['job_role'].value_counts(normalize=True).round(2)
# Out:
# attrition  job_role
# no         sales executive               0.22
#            research scientist            0.20
#            laboratory technician         0.16
#            manufacturing director        0.11
#            healthcare representative     0.10
#            manager                       0.08
#            research director             0.06
#            sales representative          0.04
#            human resources               0.03
# yes        laboratory technician         0.26
#            sales executive               0.24
#            research scientist            0.20
#            sales representative          0.14
#            human resources               0.05
#            manufacturing director        0.04
#            healthcare representative     0.04
#            manager                       0.02
#            research director             0.01
# Name: proportion, dtype: float64

# %%
df_hr.groupby('attrition')['department'].value_counts(normalize=True).round(2)
# Out:
# attrition  department
# no         research & development    0.66
#            sales                     0.28
#            human resources           0.04
#            unknown                   0.02
# yes        research & development    0.53
#            sales                     0.37
#            human resources           0.05
#            unknown                   0.04
# Name: proportion, dtype: float64

# %% [markdown]
# # 2. Análisis de Satisfacción y Clima
#   Se centra en las métricas de bienestar (job_satisfaction, environment_satisfaction, work_life_balance).

# %% [markdown]
# ### **<font color="red"> ¿Cómo se distribuye la satisfacción laboral según el nivel del puesto (job_level)?</font>**
#        * Herramienta: sns.violinplot(x='job_level', y='job_satisfaction', data=df)

# %%
sns.violinplot(data=df_hr,x="job_level",y="job_satisfaction");

# %%
sns.boxplot(data=df_hr,x="job_level",y="job_satisfaction");

# %% [markdown]
# **Yo aqui haría un groupby por job level de la media de satisfaction, para aclarar los datos**

# %%
df_hr.groupby("job_level")["job_satisfaction"].mean()
# Out:
# job_level
# 1    2.724265
# 2    2.733209
# 3    2.689498
# 4    2.716981
# 5    2.753623
# Name: job_satisfaction, dtype: float64

# %% [markdown]
# ### **<font color="red"> ¿Existe relación entre el equilibrio vida-trabajo y la satisfacción en el entorno?</font>**
#     - Herramienta: Matriz de contingencia (Heatmap) entre work_life_balance y environment_satisfaction.

# %%
tablaconting1 = pd.crosstab(df_hr["work_life_balance"], df_hr["environment_satisfaction"], normalize="index")*100;  #todas las filas suma el 100%, por ej. un 25% no está contento, por otro lado un 31% 4/4
tablaconting1.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d5886_row0_col0, #T_d5886_row0_col3, #T_d5886_row1_col1, #T_d5886_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d5886_row0_col1, #T_d5886_row0_col2, #T_d5886_row1_col3, #T_d5886_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d5886_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_d5886_row1_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_d5886_row2_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_d5886_row2_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_d5886_row2_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_d5886_row3_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_d5886_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d5886_row3_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# </style>
# <table id="T_d5886">
#   <thead>
#     <tr>
#       <th class="index_name level0" >environment_satisfaction</th>
#       <th id="T_d5886_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_d5886_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_d5886_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_d5886_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >work_life_balance</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5886_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d5886_row0_col0" class="data row0 col0" >25.000000</td>
#       <td id="T_d5886_row0_col1" class="data row0 col1" >16.250000</td>
#       <td id="T_d5886_row0_col2" class="data row0 col2" >27.500000</td>
#       <td id="T_d5886_row0_col3" class="data row0 col3" >31.250000</td>
#     </tr>
#     <tr>
#       <th id="T_d5886_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d5886_row1_col0" class="data row1 col0" >19.476744</td>
#       <td id="T_d5886_row1_col1" class="data row1 col1" >22.674419</td>
#       <td id="T_d5886_row1_col2" class="data row1 col2" >29.069767</td>
#       <td id="T_d5886_row1_col3" class="data row1 col3" >28.779070</td>
#     </tr>
#     <tr>
#       <th id="T_d5886_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d5886_row2_col0" class="data row2 col0" >18.617614</td>
#       <td id="T_d5886_row2_col1" class="data row2 col1" >19.175028</td>
#       <td id="T_d5886_row2_col2" class="data row2 col2" >30.992196</td>
#       <td id="T_d5886_row2_col3" class="data row2 col3" >31.215162</td>
#     </tr>
#     <tr>
#       <th id="T_d5886_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d5886_row3_col0" class="data row3 col0" >19.607843</td>
#       <td id="T_d5886_row3_col1" class="data row3 col1" >16.339869</td>
#       <td id="T_d5886_row3_col2" class="data row3 col2" >34.640523</td>
#       <td id="T_d5886_row3_col3" class="data row3 col3" >29.411765</td>
#     </tr>
#   </tbody>
# </table>

# %%
tablaconting2 = pd.crosstab(df_hr["work_life_balance"], df_hr["environment_satisfaction"], normalize="columns")*100;  #todas las columnas suma el 100%, por ejemplo, el 58· odia su entorno con equilibrio al 3.
tablaconting2.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_4a346_row0_col0, #T_4a346_row0_col1, #T_4a346_row0_col2, #T_4a346_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4a346_row1_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_4a346_row1_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_4a346_row1_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_4a346_row1_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_4a346_row2_col0, #T_4a346_row2_col1, #T_4a346_row2_col2, #T_4a346_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4a346_row3_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4a346_row3_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_4a346_row3_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_4a346_row3_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_4a346">
#   <thead>
#     <tr>
#       <th class="index_name level0" >environment_satisfaction</th>
#       <th id="T_4a346_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_4a346_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_4a346_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_4a346_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >work_life_balance</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a346_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4a346_row0_col0" class="data row0 col0" >7.042254</td>
#       <td id="T_4a346_row0_col1" class="data row0 col1" >4.513889</td>
#       <td id="T_4a346_row0_col2" class="data row0 col2" >4.856512</td>
#       <td id="T_4a346_row0_col3" class="data row0 col3" >5.567929</td>
#     </tr>
#     <tr>
#       <th id="T_4a346_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4a346_row1_col0" class="data row1 col0" >23.591549</td>
#       <td id="T_4a346_row1_col1" class="data row1 col1" >27.083333</td>
#       <td id="T_4a346_row1_col2" class="data row1 col2" >22.075055</td>
#       <td id="T_4a346_row1_col3" class="data row1 col3" >22.048998</td>
#     </tr>
#     <tr>
#       <th id="T_4a346_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4a346_row2_col0" class="data row2 col0" >58.802817</td>
#       <td id="T_4a346_row2_col1" class="data row2 col1" >59.722222</td>
#       <td id="T_4a346_row2_col2" class="data row2 col2" >61.368653</td>
#       <td id="T_4a346_row2_col3" class="data row2 col3" >62.360802</td>
#     </tr>
#     <tr>
#       <th id="T_4a346_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4a346_row3_col0" class="data row3 col0" >10.563380</td>
#       <td id="T_4a346_row3_col1" class="data row3 col1" >8.680556</td>
#       <td id="T_4a346_row3_col2" class="data row3 col2" >11.699779</td>
#       <td id="T_4a346_row3_col3" class="data row3 col3" >10.022272</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.heatmap(tablaconting1, annot=True, cmap="Blues", cbar=True)
# Out:
# <Axes: xlabel='environment_satisfaction', ylabel='work_life_balance'>

# %%
sns.heatmap(tablaconting2, annot=True, cmap="Blues", cbar=True)
# Out:
# <Axes: xlabel='environment_satisfaction', ylabel='work_life_balance'>

# %% [markdown]
# ### **<font color="red"> ¿Los empleados con más años bajo el mismo manager tienen mayor satisfacción?</float>**
#     - Herramienta: sns.lineplot o sns.barplot comparando years_with_curr_manager con job_satisfaction.

# %%
plt.figure(figsize= (10,6))
sns.lineplot(data=df_hr,x="years_with_curr_manager",y="job_satisfaction", hue="attrition")
plt.title('¿Cómo cae la satisfacción con el tiempo?', fontsize=15)
plt.xlabel("Años bajo el mismo manager")
plt.ylabel("Satisfacción laboral")

plt.show()

# %%
# Usamos lmplot para crear líneas de tendencia automáticas
sns.lmplot(data=df_hr, 
           x="years_with_curr_manager", 
           y="job_satisfaction", 
           hue="attrition", 
           palette="Set1",
           scatter_kws={'alpha':0.3}, # Hacemos los puntos un poco transparentes
           height=6, aspect=1.5)

# Añadimos títulos que ayuden al insight
plt.title('¿Cómo cae la satisfacción con el tiempo? (Tendencia)', fontsize=15)
plt.show()

# %%
sns.boxplot(data=df_hr,x="years_with_curr_manager",y="job_satisfaction");

# %%
df_hr["years_bin"] = pd.cut(
    df_hr["years_with_curr_manager"],
    bins=[0,3,6,10,20],
    labels=["0-3","4-6","7-10","10+"]
)

# %%
sns.boxplot(data=df_hr, x="years_bin", y="job_satisfaction");

# %%
sns.barplot(data=df_hr,y="years_with_curr_manager",x="job_satisfaction", errorbar=None);

# %% [markdown]
# # 3. Correlaciones y Factores Numéricos
#   Para identificar qué variables se mueven juntas.

# %% [markdown]
# ### **<font color="red"> ¿Cuáles son las variables numéricas que más influyen en el ingreso mensual?</font>**
#        - Herramienta: Mapa de calor de correlaciones (sns.heatmap(df.corr())) filtrando por monthly_income.

# %%
# Calculamos la matriz de correlación completa (solo numéricas)
corr_matrix = df_hr.corr(numeric_only=True)

# Usamos sort_values para poner las correlaciones más altas arriba
income_corr = corr_matrix[['monthly_income']].sort_values(by='monthly_income', ascending=False)

# 3. Graficamos el Heatmap enfocado
sns.heatmap( income_corr,annot=True,cmap='coolwarm',vmin=-1, vmax=1,fmt=".2f")
# Escala de color: azul (negativo), blanco (cero), rojo (positivo)
# Fija la escala de color de -1 a 1
# Formato de dos decimales

plt.title("Influencia Numérica en el Ingreso Mensual", fontsize=12)
plt.show()

# %%
sns.boxplot(data=df_hr, y="years_at_company", x="percent_salary_hike", hue="attrition");

# %%
sns.scatterplot(data=df_hr, x="years_at_company", y="percent_salary_hike", hue="attrition", alpha=0.6);

# %%
sns.jointplot(data=df_hr, x="years_at_company", y="percent_salary_hike", hue="attrition", kind="kde", fill=True, alpha=0.5)

# %% [markdown]
# ### **<font color="red"> ¿Existe una correlación entre el porcentaje de aumento salarial (percent_salary_hike) y el desempeño (performance_rating)?</font>**
#        * Herramienta: sns.scatterplot con regresión.

# %%
# regplot añade la línea de tendencia y el "sombreado" (intervalo de confianza)
sns.regplot(data=df_hr,x="performance_rating",y="percent_salary_hike", x_jitter=0.1, color="lightblue", line_kws={'color': 'orange'}) # x_jitter Separa un poco los puntos para ver densidad

plt.title("Relación entre Desempeño y Aumento Salarial", fontsize=14)
plt.xlabel("Desempeño")
plt.ylabel("Porcentaje de aumento salarial (%)")
plt.grid(True, linestyle='--', alpha=0.6) # Añade una rejilla para leer mejor
plt.show()

# %%
# regplot añade la línea de tendencia y el "sombreado" (intervalo de confianza)
sns.scatterplot(data=df_hr,x="performance_rating",y="percent_salary_hike", hue= "attrition")

plt.title("Relación entre Desempeño y Aumento Salarial", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6) # Añade una rejilla para leer mejor
plt.show()

# %%
# regplot añade la línea de tendencia y el "sombreado" (intervalo de confianza)
sns.barplot(data=df_hr,x="attrition",y="years_since_last_promotion", hue= "percent_salary_hike", errorbar=None)

plt.title("Relación entre Desempeño y Aumento Salarial", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6) # Añade una rejilla para leer mejor
plt.show()

# %%
sns.boxplot(data=df_hr, x="years_since_last_promotion", hue= "attrition");

# %%
df_hr.sample()
# Out:
#     attrition business_travel department  distance_from_home  education  \
# 137        no      non-travel      sales                   4          4
#
#     education_field  employee_number  environment_satisfaction  gender  \
# 137   life sciences              182                         4  female
#
#      job_involvement  job_level           job_role marital_status  \
# 137                2          2   sales executive         married
#
#      num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 137                     4        no                   14                   3
#
#      relationship_satisfaction  stock_option_level  total_working_years  \
# 137                          3                   1                   17
#
#      training_times_last_year  work_life_balance  years_at_company  \
# 137                         1                  4                15
#
#      years_in_current_role  years_since_last_promotion  \
# 137                     11                           5
#
#      years_with_curr_manager  age  job_satisfaction  monthly_income  \
# 137                      9.0   39                 3          5902.0
#
#     salary_cat distance_cat job_level_cat years_bin
# 137      medio        Cerca        junior      7-10

# %% [markdown]
# ### **<font color="red"> ¿Cómo afecta la edad y los años de experiencia al nivel de ingresos?</font>**
#     - Herramienta: sns.jointplot para ver la distribución y la relación entre age y total_working_years.

# %%
sns.scatterplot(data=df_hr, x="age",y="total_working_years");

# %%
df_hr = df_hr[df_hr['age'] > df_hr['total_working_years']]

# %%
df_hr = df_hr[(df_hr['age'] - df_hr['total_working_years']) >= 16]

# %%
sns.scatterplot(data=df_hr, x="age",y="total_working_years");

# %%
sns.scatterplot(data=df_hr, x="age",y="years_at_company");

# %%
sns.scatterplot(data=df_hr, x="age",y="years_in_current_role");

# %%
df_hr[(df_hr['total_working_years']>= 25)&(df_hr['age']<=35)] #¡OJO con los datos erróneos!
# Out:
# Empty DataFrame
# Columns: [attrition, business_travel, department, distance_from_home, education, education_field, employee_number, environment_satisfaction, gender, job_involvement, job_level, job_role, marital_status, num_companies_worked, over_time, percent_salary_hike, performance_rating, relationship_satisfaction, stock_option_level, total_working_years, training_times_last_year, work_life_balance, years_at_company, years_in_current_role, years_since_last_promotion, years_with_curr_manager, age, job_satisfaction, monthly_income, salary_cat, distance_cat, job_level_cat, years_bin]
# Index: []

# %%
sp_corr.matriz_correlacion_visual(df_hr)
# Out:
#                             distance_from_home  education  employee_number  \
# distance_from_home                    1.000000   0.017952         0.035255
# education                             0.017952   1.000000         0.039864
# employee_number                       0.035255   0.039864         1.000000
# environment_satisfaction             -0.015000  -0.029191         0.015265
# job_involvement                       0.007275   0.049638        -0.009939
# job_level                             0.006650   0.100509        -0.027961
# num_companies_worked                 -0.031085   0.130896        -0.001958
# percent_salary_hike                   0.041187  -0.009656        -0.011781
# performance_rating                    0.026836  -0.022720        -0.018809
# relationship_satisfaction             0.003783  -0.010961        -0.067267
# stock_option_level                    0.046640   0.019328         0.060248
# total_working_years                   0.002717   0.145421        -0.023686
# training_times_last_year             -0.022230  -0.041511         0.020760
# work_life_balance                    -0.024250   0.006827         0.012300
# years_at_company                      0.012052   0.059620        -0.013064
# years_in_current_role                 0.016391   0.060730        -0.003488
# years_since_last_promotion            0.009034   0.048123        -0.006602
# years_with_curr_manager               0.025193   0.067135        -0.018533
# age                                  -0.001664   0.192172        -0.016419
# job_satisfaction                     -0.004558  -0.011816        -0.049090
# monthly_income                       -0.016838   0.095597        -0.025277
#
#                             environment_satisfaction  job_involvement  \
# distance_from_home                         -0.015000         0.007275
# education                                  -0.029191         0.049638
# employee_number                             0.015265        -0.009939
# environment_satisfaction                    1.000000        -0.007659
# job_involvement                            -0.007659         1.000000
# job_level                                   0.002974        -0.007197
# num_companies_worked                        0.013301         0.010588
# percent_salary_hike                        -0.036785        -0.015932
# performance_rating                         -0.031283        -0.029955
# relationship_satisfaction                   0.008725         0.036707
# stock_option_level                          0.001702         0.021293
# total_working_years                        -0.001798         0.001988
# training_times_last_year                   -0.009799        -0.006280
# work_life_balance                           0.028295        -0.011159
# years_at_company                            0.012281        -0.010505
# years_in_current_role                       0.024493         0.010247
# years_since_last_promotion                  0.020187        -0.017340
# years_with_curr_manager                     0.009579         0.021992
# age                                         0.009307         0.021088
# job_satisfaction                           -0.020563        -0.018199
# monthly_income                             -0.007736        -0.009020
#
#                             job_level  num_companies_worked  \
# distance_from_home           0.006650             -0.031085
# education                    0.100509              0.130896
# employee_number             -0.027961             -0.001958
# environment_satisfaction     0.002974              0.013301
# job_involvement             -0.007197              0.010588
# job_level                    1.000000              0.139315
# num_companies_worked         0.139315              1.000000
# percent_salary_hike         -0.029770             -0.006644
# performance_rating          -0.015264             -0.012021
# relationship_satisfaction    0.017514              0.050438
# stock_option_level           0.018527              0.031422
# total_working_years          0.778335              0.238563
# training_times_last_year    -0.011918             -0.072079
# work_life_balance            0.038671             -0.004567
# years_at_company             0.530384             -0.123732
# years_in_current_role        0.392052             -0.095385
# years_since_last_promotion   0.350506             -0.038157
# years_with_curr_manager      0.338738             -0.108998
# age                          0.499972              0.296066
# job_satisfaction            -0.005369             -0.050468
# monthly_income               0.949349              0.147201
#
#                             percent_salary_hike  performance_rating  \
# distance_from_home                     0.041187            0.026836
# education                             -0.009656           -0.022720
# employee_number                       -0.011781           -0.018809
# environment_satisfaction              -0.036785           -0.031283
# job_involvement                       -0.015932           -0.029955
# job_level                             -0.029770           -0.015264
# num_companies_worked                  -0.006644           -0.012021
# percent_salary_hike                    1.000000            0.774217
# performance_rating                     0.774217            1.000000
# relationship_satisfaction             -0.040994           -0.030899
# stock_option_level                     0.005593            0.002292
# total_working_years                   -0.014042            0.014540
# training_times_last_year              -0.005607           -0.023146
# work_life_balance                     -0.006298            0.001617
# years_at_company                      -0.030959            0.011479
# years_in_current_role                  0.003308            0.038057
# years_since_last_promotion            -0.023682            0.021698
# years_with_curr_manager               -0.009131            0.017598
# age                                    0.004584            0.007452
# job_satisfaction                       0.015215            0.003752
# monthly_income                        -0.022990           -0.011123
#
#                             relationship_satisfaction  stock_option_level  \
# distance_from_home                           0.003783            0.046640
# education                                   -0.010961            0.019328
# employee_number                             -0.067267            0.060248
# environment_satisfaction                     0.008725            0.001702
# job_involvement                              0.036707            0.021293
# job_level                                    0.017514            0.018527
# num_companies_worked                         0.050438            0.031422
# percent_salary_hike                         -0.040994            0.005593
# performance_rating                          -0.030899            0.002292
# relationship_satisfaction                    1.000000           -0.044591
# stock_option_level                          -0.044591            1.000000
# total_working_years                          0.016944            0.015311
# training_times_last_year                     0.008696            0.015076
# work_life_balance                            0.019421            0.003767
# years_at_company                             0.012483            0.023446
# years_in_current_role                       -0.019313            0.053709
# years_since_last_promotion                   0.024470            0.022650
# years_with_curr_manager                     -0.017492            0.029149
# age                                          0.035374            0.042509
# job_satisfaction                            -0.012227            0.015802
# monthly_income                               0.022018            0.008915
#
#                             total_working_years  training_times_last_year  \
# distance_from_home                     0.002717                 -0.022230
# education                              0.145421                 -0.041511
# employee_number                       -0.023686                  0.020760
# environment_satisfaction              -0.001798                 -0.009799
# job_involvement                        0.001988                 -0.006280
# job_level                              0.778335                 -0.011918
# num_companies_worked                   0.238563                 -0.072079
# percent_salary_hike                   -0.014042                 -0.005607
# performance_rating                     0.014540                 -0.023146
# relationship_satisfaction              0.016944                  0.008696
# stock_option_level                     0.015311                  0.015076
# total_working_years                    1.000000                 -0.034856
# training_times_last_year              -0.034856                  1.000000
# work_life_balance                      0.002698                  0.025629
# years_at_company                       0.617497                  0.002378
# years_in_current_role                  0.460361                 -0.021011
# years_since_last_promotion             0.400014                  0.004109
# years_with_curr_manager                0.429273                  0.008822
# age                                    0.667589                 -0.035193
# job_satisfaction                      -0.026048                 -0.011020
# monthly_income                         0.769094                 -0.017084
#
#                             work_life_balance  years_at_company  \
# distance_from_home                  -0.024250          0.012052
# education                            0.006827          0.059620
# employee_number                      0.012300         -0.013064
# environment_satisfaction             0.028295          0.012281
# job_involvement                     -0.011159         -0.010505
# job_level                            0.038671          0.530384
# num_companies_worked                -0.004567         -0.123732
# percent_salary_hike                 -0.006298         -0.030959
# performance_rating                   0.001617          0.011479
# relationship_satisfaction            0.019421          0.012483
# stock_option_level                   0.003767          0.023446
# total_working_years                  0.002698          0.617497
# training_times_last_year             0.025629          0.002378
# work_life_balance                    1.000000          0.010956
# years_at_company                     0.010956          1.000000
# years_in_current_role                0.051809          0.767623
# years_since_last_promotion           0.006378          0.617890
# years_with_curr_manager              0.002732          0.720517
# age                                 -0.022184          0.298325
# job_satisfaction                    -0.022909         -0.005000
# monthly_income                       0.032287          0.511422
#
#                             years_in_current_role  years_since_last_promotion  \
# distance_from_home                       0.016391                    0.009034
# education                                0.060730                    0.048123
# employee_number                         -0.003488                   -0.006602
# environment_satisfaction                 0.024493                    0.020187
# job_involvement                          0.010247                   -0.017340
# job_level                                0.392052                    0.350506
# num_companies_worked                    -0.095385                   -0.038157
# percent_salary_hike                      0.003308                   -0.023682
# performance_rating                       0.038057                    0.021698
# relationship_satisfaction               -0.019313                    0.024470
# stock_option_level                       0.053709                    0.022650
# total_working_years                      0.460361                    0.400014
# training_times_last_year                -0.021011                    0.004109
# work_life_balance                        0.051809                    0.006378
# years_at_company                         0.767623                    0.617890
# years_in_current_role                    1.000000                    0.550587
# years_since_last_promotion               0.550587                    1.000000
# years_with_curr_manager                  0.663702                    0.491859
# age                                      0.206053                    0.201201
# job_satisfaction                         0.001355                   -0.020107
# monthly_income                           0.368410                    0.340737
#
#                             years_with_curr_manager       age  \
# distance_from_home                         0.025193 -0.001664
# education                                  0.067135  0.192172
# employee_number                           -0.018533 -0.016419
# environment_satisfaction                   0.009579  0.009307
# job_involvement                            0.021992  0.021088
# job_level                                  0.338738  0.499972
# num_companies_worked                      -0.108998  0.296066
# percent_salary_hike                       -0.009131  0.004584
# performance_rating                         0.017598  0.007452
# relationship_satisfaction                 -0.017492  0.035374
# stock_option_level                         0.029149  0.042509
# total_working_years                        0.429273  0.667589
# training_times_last_year                   0.008822 -0.035193
# work_life_balance                          0.002732 -0.022184
# years_at_company                           0.720517  0.298325
# years_in_current_role                      0.663702  0.206053
# years_since_last_promotion                 0.491859  0.201201
# years_with_curr_manager                    1.000000  0.191508
# age                                        0.191508  1.000000
# job_satisfaction                          -0.010139 -0.027739
# monthly_income                             0.310190  0.487044
#
#                             job_satisfaction  monthly_income
# distance_from_home                 -0.004558       -0.016838
# education                          -0.011816        0.095597
# employee_number                    -0.049090       -0.025277
# environment_satisfaction           -0.020563       -0.007736
# job_involvement                    -0.018199       -0.009020
# job_level                          -0.005369        0.949349
# num_companies_worked               -0.050468        0.147201
# percent_salary_hike                 0.015215       -0.022990
# performance_rating                  0.003752       -0.011123
# relationship_satisfaction          -0.012227        0.022018
# stock_option_level                  0.015802        0.008915
# total_working_years                -0.026048        0.769094
# training_times_last_year           -0.011020       -0.017084
# work_life_balance                  -0.022909        0.032287
# years_at_company                   -0.005000        0.511422
# years_in_current_role               0.001355        0.368410
# years_since_last_promotion         -0.020107        0.340737
# years_with_curr_manager            -0.010139        0.310190
# age                                -0.027739        0.487044
# job_satisfaction                    1.000000       -0.011427
# monthly_income                     -0.011427        1.000000

# %%
df_yes = df_hr[df_hr["attrition"] == "yes"]

# %%
df_no = df_hr[df_hr["attrition"] == "no"]

# %%
df_yes.sample(5)
# Out:
#      attrition    business_travel              department  distance_from_home  \
# 1326       yes      travel_rarely                   sales                   2
# 1032       yes         non-travel  research & development                   2
# 838        yes  travel_frequently                   sales                  12
# 357        yes  travel_frequently                   sales                   1
# 293        yes      travel_rarely                   sales                   4
#
#       education   education_field  employee_number  environment_satisfaction  \
# 1326          4         marketing             1862                         3
# 1032          3     life sciences             1458                         1
# 838           3     life sciences             1167                         3
# 357           1  technical degree              478                         1
# 293           4         marketing              401                         4
#
#       gender  job_involvement  job_level                 job_role  \
# 1326    male                2          2         sales executive
# 1032  female                2          1   laboratory technician
# 838     male                3          4         sales executive
# 357   female                2          1    sales representative
# 293     male                2          2         sales executive
#
#      marital_status  num_companies_worked over_time  percent_salary_hike  \
# 1326        unknown                     7       yes                   12
# 1032         single                     2       yes                   23
# 838          single                     0       yes                   12
# 357          single                     1       yes                   11
# 293          single                     1       yes                   12
#
#       performance_rating  relationship_satisfaction  stock_option_level  \
# 1326                   3                          3                   0
# 1032                   4                          2                   0
# 838                    3                          2                   0
# 357                    3                          3                   0
# 293                    3                          2                   0
#
#       total_working_years  training_times_last_year  work_life_balance  \
# 1326                    7                         3                  2
# 1032                   11                         2                  4
# 838                    22                         2                  2
# 357                     3                         3                  3
# 293                     8                         0                  3
#
#       years_at_company  years_in_current_role  years_since_last_promotion  \
# 1326                 2                      2                           2
# 1032                 1                      0                           0
# 838                 21                      9                          13
# 357                  3                      2                           1
# 293                  8                      7                           7
#
#       years_with_curr_manager  age  job_satisfaction  monthly_income  \
# 1326                      2.0   32                 2          9907.0
# 1032                      0.0   39                 1          3646.0
# 838                      14.0   42                 1         13758.0
# 357                       2.0   21                 2          2174.0
# 293                       4.0   26                 4          5828.0
#
#      salary_cat distance_cat job_level_cat years_bin
# 1326      medio        Cerca        junior       0-3
# 1032       bajo        Cerca           NaN       NaN
# 838        alto        Medio        senior       10+
# 357        bajo        Cerca           NaN       0-3
# 293       medio        Cerca        junior       4-6

# %%
df_no.sample(5)
# Out:
#      attrition business_travel              department  distance_from_home  \
# 840         no   travel_rarely  research & development                   1
# 502         no   travel_rarely                   sales                   1
# 261         no      non-travel                   sales                   2
# 945         no   travel_rarely  research & development                  28
# 1088        no   travel_rarely  research & development                   2
#
#       education education_field  employee_number  environment_satisfaction  \
# 840           4         medical             1172                         4
# 502           1         medical              682                         4
# 261           2   life sciences              361                         4
# 945           3   life sciences             1317                         4
# 1088          3         medical             1542                         3
#
#       gender  job_involvement  job_level                 job_role  \
# 840     male                2          1   laboratory technician
# 502   female                3          2         sales executive
# 261     male                2          2         sales executive
# 945   female                3          4       research director
# 1088    male                2          1   laboratory technician
#
#      marital_status  num_companies_worked over_time  percent_salary_hike  \
# 840         married                     6        no                   12
# 502          single                     7        no                   20
# 261         married                     3        no                   18
# 945         married                     4       yes                   11
# 1088        married                     4        no                   14
#
#       performance_rating  relationship_satisfaction  stock_option_level  \
# 840                    3                          2                   1
# 502                    4                          4                   0
# 261                    3                          4                   1
# 945                    3                          2                   0
# 1088                   3                          2                   1
#
#       total_working_years  training_times_last_year  work_life_balance  \
# 840                    10                         2                  3
# 502                    18                         2                  4
# 261                    13                         0                  3
# 945                    25                         2                  3
# 1088                    4                         3                  3
#
#       years_at_company  years_in_current_role  years_since_last_promotion  \
# 840                  8                      0                           1
# 502                 14                      7                           8
# 261                  8                      7                           7
# 945                  3                      2                           1
# 1088                 1                      0                           0
#
#       years_with_curr_manager  age  job_satisfaction  monthly_income  \
# 840                       7.0   35                 3          2258.0
# 502                      10.0   53                 1          8381.0
# 261                       5.0   38                 4          5249.0
# 945                       2.0   50                 1         16880.0
# 1088                      0.0   42                 2          4841.0
#
#      salary_cat distance_cat job_level_cat years_bin
# 840        bajo        Cerca           NaN      7-10
# 502       medio        Cerca        junior      7-10
# 261       medio        Cerca        junior       4-6
# 945        alto        Lejos        senior       0-3
# 1088       bajo        Cerca           NaN       NaN

# %%
df_yes.describe(include=np.number).T.round(2)
# Out:
#                             count     mean      std     min     25%     50%  \
# distance_from_home          237.0    10.72     8.47     1.0     3.0     9.0
# education                   237.0     2.82     1.01     1.0     2.0     3.0
# employee_number             237.0  1010.95   581.41     1.0   514.0  1017.0
# environment_satisfaction    237.0     2.47     1.17     1.0     1.0     3.0
# job_involvement             237.0     2.51     0.78     1.0     2.0     3.0
# job_level                   237.0     1.63     0.94     1.0     1.0     1.0
# num_companies_worked        237.0     2.95     2.67     0.0     1.0     1.0
# percent_salary_hike         237.0    15.08     3.78    11.0    12.0    14.0
# performance_rating          237.0     3.16     0.36     3.0     3.0     3.0
# relationship_satisfaction   237.0     2.60     1.13     1.0     2.0     3.0
# stock_option_level          237.0     0.53     0.86     0.0     0.0     0.0
# total_working_years         237.0     8.11     6.98     0.0     3.0     7.0
# training_times_last_year    237.0     2.47     1.36     0.0     2.0     2.0
# work_life_balance           237.0     2.66     0.82     1.0     2.0     3.0
# years_at_company            237.0     5.00     5.67     0.0     1.0     3.0
# years_in_current_role       237.0     2.87     3.17     0.0     0.0     2.0
# years_since_last_promotion  237.0     1.94     3.16     0.0     0.0     1.0
# years_with_curr_manager     237.0     2.95     2.99     0.0     0.0     2.0
# age                         237.0    33.75     9.41    18.0    28.0    32.0
# job_satisfaction            237.0     2.47     1.10     1.0     1.0     3.0
# monthly_income              237.0  4744.43  3624.43  1009.0  2367.0  3172.0
#
#                                75%      max
# distance_from_home            17.0     29.0
# education                      4.0      5.0
# employee_number             1486.0   2055.0
# environment_satisfaction       4.0      4.0
# job_involvement                3.0      4.0
# job_level                      2.0      5.0
# num_companies_worked           5.0      9.0
# percent_salary_hike           17.0     25.0
# performance_rating             3.0      4.0
# relationship_satisfaction      4.0      4.0
# stock_option_level             1.0      3.0
# total_working_years           10.0     40.0
# training_times_last_year       3.0      6.0
# work_life_balance              3.0      4.0
# years_at_company               7.0     40.0
# years_in_current_role          4.0     15.0
# years_since_last_promotion     2.0     15.0
# years_with_curr_manager        4.0     14.0
# age                           39.0     58.0
# job_satisfaction               3.0      4.0
# monthly_income              5828.0  19859.0

# %%
df_no.describe(include=np.number).T.round(2)
# Out:
#                              count     mean      std     min      25%     50%  \
# distance_from_home          1226.0     8.91     8.00     1.0     2.00     7.0
# education                   1226.0     2.92     1.03     1.0     2.00     3.0
# employee_number             1226.0  1024.86   606.33     2.0   481.25  1016.5
# environment_satisfaction    1226.0     2.78     1.07     1.0     2.00     3.0
# job_involvement             1226.0     2.77     0.69     1.0     2.00     3.0
# job_level                   1226.0     2.13     1.10     1.0     1.00     2.0
# num_companies_worked        1226.0     2.63     2.46     0.0     1.00     2.0
# percent_salary_hike         1226.0    15.24     3.64    11.0    12.00    14.0
# performance_rating          1226.0     3.15     0.36     3.0     3.00     3.0
# relationship_satisfaction   1226.0     2.73     1.07     1.0     2.00     3.0
# stock_option_level          1226.0     0.85     0.84     0.0     0.00     1.0
# total_working_years         1226.0    11.73     7.65     0.0     6.00    10.0
# training_times_last_year    1226.0     2.66     1.44     0.0     2.00     3.0
# work_life_balance           1226.0     2.78     0.68     1.0     2.00     3.0
# years_at_company            1226.0     7.27     5.95     0.0     3.00     5.0
# years_in_current_role       1226.0     4.46     3.64     0.0     2.00     3.0
# years_since_last_promotion  1226.0     2.20     3.19     0.0     0.00     1.0
# years_with_curr_manager     1226.0     4.13     3.37     0.0     2.00     3.0
# age                         1226.0    37.54     8.70    18.0    31.00    36.0
# job_satisfaction            1226.0     2.77     1.09     1.0     2.00     3.0
# monthly_income              1226.0  6759.85  4744.06  1051.0  3205.50  5189.5
#
#                                 75%      max
# distance_from_home            13.00     29.0
# education                      4.00      5.0
# employee_number             1567.00   2068.0
# environment_satisfaction       4.00      4.0
# job_involvement                3.00      4.0
# job_level                      3.00      5.0
# num_companies_worked           4.00      9.0
# percent_salary_hike           18.00     25.0
# performance_rating             3.00      4.0
# relationship_satisfaction      4.00      4.0
# stock_option_level             1.00      3.0
# total_working_years           16.00     38.0
# training_times_last_year       3.00      6.0
# work_life_balance              3.00      4.0
# years_at_company              10.00     37.0
# years_in_current_role          7.00     18.0
# years_since_last_promotion     3.00     15.0
# years_with_curr_manager        7.00     17.0
# age                           43.00     60.0
# job_satisfaction               4.00      4.0
# monthly_income              8674.25  19999.0

# %%
tabla = pd.crosstab(df_hr["attrition"], df_hr["job_involvement"], normalize="columns")
sns.heatmap(tabla, annot=True);
