# %%
import pandas as pd
import numpy as np

# necesitamos importar una librería especifica
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer

#necesitamos importar el fichero src creado
from src import soporte_funciones as sp_fun

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

## Controlamos las advertencias
import warnings 
warnings.filterwarnings('ignore', category=FutureWarning) # Para ignorar las advertencias de tipo FutureWarning

# %%
df_talento = pd.read_csv("files/hr.csv")

# %%
df_talento.head(10)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
# 2  37.0       Yes      Travel_Rarely       1373  Research & Development
# 3  33.0        No  Travel_Frequently       1392  Research & Development
# 4  27.0        No      Travel_Rarely        591  Research & Development
# 5  32.0        No  Travel_Frequently       1005  Research & Development
# 6  59.0        No      Travel_Rarely       1324  Research & Development
# 7  30.0        No      Travel_Rarely       1358                     NaN
# 8  38.0        No  Travel_Frequently        216  Research & Development
# 9  36.0        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
# 5                 2          2  Life Sciences              1               8
# 6                 3          3        Medical              1              10
# 7                24          1  Life Sciences              1              11
# 8                23          3  Life Sciences              1              12
# 9                27          3            NaN              1              13
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
# 5                        4    Male          79               3         1
# 6                        3  Female          81               4         1
# 7                        4    Male          67               3         1
# 8                        4    Male          44               2         3
# 9                        3    Male          94               3         2
#
#                        JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0             sALES eXECUTIVE               4.0        Single         5993.0
# 1          rESEARCH sCIENTIST               2.0       Married         5130.0
# 2       lABORATORY tECHNICIAN               3.0        Single         2090.0
# 3          rESEARCH sCIENTIST               3.0       Married         2909.0
# 4       lABORATORY tECHNICIAN               2.0       Married         3468.0
# 5       lABORATORY tECHNICIAN               4.0        Single         3068.0
# 6       lABORATORY tECHNICIAN               1.0       Married         2670.0
# 7       lABORATORY tECHNICIAN               3.0      Divorced         2693.0
# 8      mANUFACTURING dIRECTOR               3.0        Single         9526.0
# 9   hEALTHCARE rEPRESENTATIVE               3.0       Married         5237.0
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
# 5        11864                   0      Y       No                 13
# 6         9964                   4      Y      NaN                 20
# 7        13335                   1      Y       No                 22
# 8         8787                   0      Y       No                 21
# 9        16577                   6      Y       No                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1           80.0
# 1                  4                         4            NaN
# 2                  3                         2            NaN
# 3                  3                         3           80.0
# 4                  3                         4           80.0
# 5                  3                         3           80.0
# 6                  4                         1            NaN
# 7                  4                         2           80.0
# 8                  4                         2           80.0
# 9                  3                         2           80.0
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                    0.0
# 1                 1                 10                    3.0
# 2                 0                  7                    3.0
# 3                 0                  8                    3.0
# 4                 1                  6                    3.0
# 5                 0                  8                    2.0
# 6                 3                 12                    3.0
# 7                 1                  1                    2.0
# 8                 0                 10                    2.0
# 9                 2                 17                    3.0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
# 5                2               7                   7
# 6                2               1                   0
# 7                3               1                   0
# 8                3               9                   7
# 9                2               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                   5.0
# 1                        1                   7.0
# 2                        0                   0.0
# 3                        3                   0.0
# 4                        2                   2.0
# 5                        3                   6.0
# 6                        0                   NaN
# 7                        0                   0.0
# 8                        1                   8.0
# 9                        7                   NaN

# %%
df_talento.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
pd.Series(df_talento.columns)
# Out:
# 0                          Age
# 1                    Attrition
# 2               BusinessTravel
# 3                    DailyRate
# 4                   Department
# 5             DistanceFromHome
# 6                    Education
# 7               EducationField
# 8                EmployeeCount
# 9               EmployeeNumber
# 10     EnvironmentSatisfaction
# 11                      Gender
# 12                  HourlyRate
# 13              JobInvolvement
# 14                    JobLevel
# 15                     JobRole
# 16             JobSatisfaction
# 17               MaritalStatus
# 18               MonthlyIncome
# 19                 MonthlyRate
# 20          NumCompaniesWorked
# 21                      Over18
# 22                    OverTime
# 23           PercentSalaryHike
# 24           PerformanceRating
# 25    RelationshipSatisfaction
# 26               StandardHours
# 27            StockOptionLevel
# 28           TotalWorkingYears
# 29       TrainingTimesLastYear
# 30             WorkLifeBalance
# 31              YearsAtCompany
# 32          YearsInCurrentRole
# 33     YearsSinceLastPromotion
# 34        YearsWithCurrManager
# dtype: str

# %%
df_talento.shape #aqui vemos el número de filas, columnas
# Out:
# (1474, 35)

# %%
df_talento.info() #aqui vemos el tipo de datos, los nulos, columnas, etc
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1401 non-null   float64
#  1   Attrition                 1474 non-null   str
#  2   BusinessTravel            1357 non-null   str
#  3   DailyRate                 1474 non-null   int64
#  4   Department                1445 non-null   str
#  5   DistanceFromHome          1474 non-null   int64
#  6   Education                 1474 non-null   int64
#  7   EducationField            1416 non-null   str
#  8   EmployeeCount             1474 non-null   int64
#  9   EmployeeNumber            1474 non-null   int64
#  10  EnvironmentSatisfaction   1474 non-null   int64
#  11  Gender                    1474 non-null   str
#  12  HourlyRate                1474 non-null   int64
#  13  JobInvolvement            1474 non-null   int64
#  14  JobLevel                  1474 non-null   int64
#  15  JobRole                   1474 non-null   str
#  16  JobSatisfaction           1445 non-null   float64
#  17  MaritalStatus             1342 non-null   str
#  18  MonthlyIncome             1460 non-null   float64
#  19  MonthlyRate               1474 non-null   int64
#  20  NumCompaniesWorked        1474 non-null   int64
#  21  Over18                    1474 non-null   str
#  22  OverTime                  1430 non-null   str
#  23  PercentSalaryHike         1474 non-null   int64
#  24  PerformanceRating         1474 non-null   int64
#  25  RelationshipSatisfaction  1474 non-null   int64
#  26  StandardHours             1310 non-null   float64
#  27  StockOptionLevel          1474 non-null   int64
#  28  TotalWorkingYears         1474 non-null   int64
#  29  TrainingTimesLastYear     1386 non-null   float64
#  30  WorkLifeBalance           1474 non-null   int64
#  31  YearsAtCompany            1474 non-null   int64
#  32  YearsInCurrentRole        1474 non-null   int64
#  33  YearsSinceLastPromotion   1474 non-null   int64
#  34  YearsWithCurrManager      1326 non-null   float64
# dtypes: float64(6), int64(20), str(9)
# memory usage: 403.2 KB

# %%
df_talento.duplicated().sum() #supuestamente hay 4 duplicados.
# Out:
# np.int64(4)

# %% [markdown]
# ## columnas a modificar tras primera visualización
#
# Age: float a int?
#
# César:
#
# - Attrition - Baja personal o rotación general
# - DailyRate - Tarifa diaria, en código, dinero ??
# - HourlyRate - Tarifa horaria, código o dinero ??
# - JobLevel - Nivel de puesto ( jefe - intermedio - "peón")

# %%
df_talento[["MonthlyIncome", "MonthlyRate"]].sample(10)
# Out:
#       MonthlyIncome  MonthlyRate
# 955         19187.0         6992
# 752          2743.0         8269
# 1150         5208.0        26312
# 242          3072.0        19877
# 1451         5343.0         5982
# 393          6538.0        12740
# 1114         2367.0        16530
# 1306         9637.0         8277
# 1443        18880.0        17312
# 23           1232.0        19281

# %% [markdown]
# # Analizamos si hay cierta coherencia entre el salario, y ratio de salario.

# %%
df_talento["ProfitMargen"] = (1 - df_talento["MonthlyIncome"] / df_talento["MonthlyRate"]) * 100

# %%
display(round(df_talento[["ProfitMargen", "MonthlyRate", "MonthlyIncome", "JobRole"]]), 2)
# Out:
#       ProfitMargen  MonthlyRate  MonthlyIncome                   JobRole
# 0             69.0        19479         5993.0          sALES eXECUTIVE
# 1             79.0        24907         5130.0       rESEARCH sCIENTIST
# 2             13.0         2396         2090.0    lABORATORY tECHNICIAN
# 3             87.0        23159         2909.0       rESEARCH sCIENTIST
# 4             79.0        16632         3468.0    lABORATORY tECHNICIAN
# ...            ...          ...            ...                       ...
# 1469          57.0        10228         4404.0    lABORATORY tECHNICIAN
# 1470          64.0        23490         8463.0          sALES eXECUTIVE
# 1471          83.0        26250         4450.0   mANUFACTURING dIRECTOR
# 1472          87.0        11585         1555.0          hUMAN rESOURCES
# 1473          48.0        18787         9724.0       rESEARCH sCIENTIST
#
# [1474 rows x 4 columns]
# 2

# %%
df_talento["DailyRate"].sample(10).reset_index()
# Out:
#    index  DailyRate
# 0    269       1403
# 1    707       1379
# 2    669       1122
# 3    648       1231
# 4     70       1225
# 5   1029        663
# 6   1177        813
# 7    667       1085
# 8    405        688
# 9    993       1372

# %%
round(df_talento.isna().sum()/df_talento.shape[0] * 100), 2
# Out:
# (Age                          5.0
#  Attrition                    0.0
#  BusinessTravel               8.0
#  DailyRate                    0.0
#  Department                   2.0
#  DistanceFromHome             0.0
#  Education                    0.0
#  EducationField               4.0
#  EmployeeCount                0.0
#  EmployeeNumber               0.0
#  EnvironmentSatisfaction      0.0
#  Gender                       0.0
#  HourlyRate                   0.0
#  JobInvolvement               0.0
#  JobLevel                     0.0
#  JobRole                      0.0
#  JobSatisfaction              2.0
#  MaritalStatus                9.0
#  MonthlyIncome                1.0
#  MonthlyRate                  0.0
#  NumCompaniesWorked           0.0
#  Over18                       0.0
#  OverTime                     3.0
#  PercentSalaryHike            0.0
#  PerformanceRating            0.0
#  RelationshipSatisfaction     0.0
#  StandardHours               11.0
#  StockOptionLevel             0.0
#  TotalWorkingYears            0.0
#  TrainingTimesLastYear        6.0
#  WorkLifeBalance              0.0
#  YearsAtCompany               0.0
#  YearsInCurrentRole           0.0
#  YearsSinceLastPromotion      0.0
#  YearsWithCurrManager        10.0
#  ProfitMargen                 1.0
#  dtype: float64,
#  2)

# %%
df_talento["Over18"].unique()
# Out:
# <StringArray>
# ['Y']
# Length: 1, dtype: str

# %% [markdown]
# Comprobamos que la columna "Over18" tiene un valor único, no es representativo

# %%
df_talento.sample()
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 155  29.0        No     Non-Travel       1496  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 155                 1          1  Technical Degree              1
#
#      EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 155             208                        4   Male          41
#
#      JobInvolvement  JobLevel                   JobRole  JobSatisfaction  \
# 155               3         2   mANUFACTURING dIRECTOR               3.0
#
#     MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 155       Married         4319.0        26283                   1      Y
#
#     OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 155       No                 13                  3                         1
#
#      StandardHours  StockOptionLevel  TotalWorkingYears  \
# 155           80.0                 1                 10
#
#      TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 155                    1.0                3              10
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 155                   7                        0                   9.0
#
#      ProfitMargen
# 155     83.567325

# %%
df_talento["EmployeeCount"].unique()
# Out:
# array([1])

# %% [markdown]
# Comprobamos que la columna "EmployeeCount" tiene un valor único, no es representativo

# %%
df_talento["JobSatisfaction"].isna().sum()
# Out:
# np.int64(29)

# %%
df_talento["Age"].isna().sum()
# Out:
# np.int64(73)

# %%
df_talento["Age"].dtype
# Out:
# dtype('float64')

# %%
#ponemos en minusculas los datos de la columba JobRole para tener los datos coherentes
# 
df_talento["JobRole"] = df_talento["JobRole"].str.lower()

# %%
df_talento["JobRole"]
# Out:
# 0               sales executive
# 1            research scientist
# 2         laboratory technician
# 3            research scientist
# 4         laboratory technician
#                   ...
# 1469      laboratory technician
# 1470            sales executive
# 1471     manufacturing director
# 1472            human resources
# 1473         research scientist
# Name: JobRole, Length: 1474, dtype: str

# %%
df_talento.duplicated().sum()
# Out:
# np.int64(4)

# %%
df_talento["JobRole"].str.strip().str.capitalize()
#capitalizamos los valores en JobRole para una mejor lectura
# Out:
# 0              Sales executive
# 1           Research scientist
# 2        Laboratory technician
# 3           Research scientist
# 4        Laboratory technician
#                  ...
# 1469     Laboratory technician
# 1470           Sales executive
# 1471    Manufacturing director
# 1472           Human resources
# 1473        Research scientist
# Name: JobRole, Length: 1474, dtype: str

# %% [markdown]
# Función para sacar datos de los dataframes y las columnas

# %%
sp_fun.info_df(df_talento)
# Out:
# Informacion sobre el dataframe:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1401 non-null   float64
#  1   Attrition                 1474 non-null   str
#  2   BusinessTravel            1357 non-null   str
#  3   DailyRate                 1474 non-null   int64
#  4   Department                1445 non-null   str
#  5   DistanceFromHome          1474 non-null   int64
#  6   Education                 1474 non-null   int64
#  7   EducationField            1416 non-null   str
#  8   EmployeeCount             1474 non-null   int64
#  9   EmployeeNumber            1474 non-null   int64
#  10  EnvironmentSatisfaction   1474 non-null   int64
#  11  Gender                    1474 non-null   str
#  12  HourlyRate                1474 non-null   int64
#  13  JobInvolvement            1474 non-null   int64
#  14  JobLevel                  1474 non-null   int64
#  15  JobRole                   1474 non-null   str
#  16  JobSatisfaction           1445 non-null   float64
#  17  MaritalStatus             1342 non-null   str
#  18  MonthlyIncome             1460 non-null   float64
#  19  MonthlyRate               1474 non-null   int64
#  20  NumCompaniesWorked        1474 non-null   int64
#  21  Over18                    1474 non-null   str
#  22  OverTime                  1430 non-null   str
#  23  PercentSalaryHike         1474 non-null   int64
#  24  PerformanceRating         1474 non-null   int64
#  25  RelationshipSatisfaction  1474 non-null   int64
#  26  StandardHours             1310 non-null   float64
#  27  StockOptionLevel          1474 non-null   int64
#  28  TotalWorkingYears         1474 non-null   int64
#  29  TrainingTimesLastYear     1386 non-null   float64
#  30  WorkLifeBalance           1474 non-null   int64
#  31  YearsAtCompany            1474 non-null   int64
#  32  YearsInCurrentRole        1474 non-null   int64
#  33  YearsSinceLastPromotion   1474 non-null   int64
#  34  YearsWithCurrManager      1326 non-null   float64
#  35  ProfitMargen              1460 non-null   float64
# dtypes: float64(7), int64(20), str(9)
# memory usage: 414.7 KB
# ----------------------------------------------------------------------------------------------------
# La descripcion del dataframe de strings:
#                count unique                     top  freq
# Attrition       1474      2                      No  1236
# BusinessTravel  1357      3           Travel_Rarely   955
# Department      1445      3  Research & Development   941
# EducationField  1416      6           Life Sciences   582
# Gender          1474      2                    Male   885
# JobRole         1474      9        sales executive    327
# MaritalStatus   1342      4                 Married   604
# Over18          1474      1                       Y  1474
# OverTime        1430      2                      No  1025
# 2
# ----------------------------------------------------------------------------------------------------
# La descripcion del dataframe numérico:
#                            count     mean     std     min     25%      50%  \
# Age                       1401.0     37.0     9.0    18.0    30.0     36.0
# DailyRate                 1474.0    803.0   404.0   102.0   465.0    803.0
# DistanceFromHome          1474.0      9.0     8.0     1.0     2.0      7.0
# Education                 1474.0      3.0     1.0     1.0     2.0      3.0
# EmployeeCount             1474.0      1.0     0.0     1.0     1.0      1.0
# EmployeeNumber            1474.0   1024.0   602.0     1.0   489.0   1020.0
# EnvironmentSatisfaction   1474.0      3.0     1.0     1.0     2.0      3.0
# HourlyRate                1474.0     66.0    20.0    30.0    48.0     66.0
# JobInvolvement            1474.0      3.0     1.0     1.0     2.0      3.0
# JobLevel                  1474.0      2.0     1.0     1.0     1.0      2.0
# JobSatisfaction           1445.0      3.0     1.0     1.0     2.0      3.0
# MonthlyIncome             1460.0   6497.0  4706.0  1009.0  2909.0   4907.0
# MonthlyRate               1474.0  14329.0  7120.0  2094.0  8054.0  14248.0
# NumCompaniesWorked        1474.0      3.0     2.0     0.0     1.0      2.0
# PercentSalaryHike         1474.0     15.0     4.0    11.0    12.0     14.0
# PerformanceRating         1474.0      3.0     0.0     3.0     3.0      3.0
# RelationshipSatisfaction  1474.0      3.0     1.0     1.0     2.0      3.0
# StandardHours             1310.0     80.0     0.0    80.0    80.0     80.0
# StockOptionLevel          1474.0      1.0     1.0     0.0     0.0      1.0
# TotalWorkingYears         1474.0     11.0     8.0     0.0     6.0     10.0
# TrainingTimesLastYear     1386.0      3.0     1.0     0.0     2.0      3.0
# WorkLifeBalance           1474.0      3.0     1.0     1.0     2.0      3.0
# YearsAtCompany            1474.0      7.0     6.0     0.0     3.0      5.0
# YearsInCurrentRole        1474.0      4.0     4.0     0.0     2.0      3.0
# YearsSinceLastPromotion   1474.0      2.0     3.0     0.0     0.0      1.0
# YearsWithCurrManager      1326.0      4.0     4.0     0.0     2.0      3.0
# ProfitMargen              1460.0     33.0    84.0  -818.0    23.0     60.0
#
#                               75%      max
# Age                          43.0     60.0
# DailyRate                  1157.0   1499.0
# DistanceFromHome             14.0     29.0
# Education                     4.0      5.0
# EmployeeCount                 1.0      1.0
# EmployeeNumber             1556.0   2068.0
# EnvironmentSatisfaction       4.0      4.0
# HourlyRate                   84.0    100.0
# JobInvolvement                3.0      4.0
# JobLevel                      3.0      5.0
# JobSatisfaction               4.0      4.0
# MonthlyIncome              8377.0  19999.0
# MonthlyRate               20466.0  26999.0
# NumCompaniesWorked            4.0      9.0
# PercentSalaryHike            18.0     25.0
# PerformanceRating             3.0      4.0
# RelationshipSatisfaction      4.0      4.0
# StandardHours                80.0     80.0
# StockOptionLevel              1.0      3.0
# TotalWorkingYears            15.0     40.0
# TrainingTimesLastYear         3.0      6.0
# WorkLifeBalance               3.0      4.0
# YearsAtCompany                9.0     40.0
# YearsInCurrentRole            7.0     18.0
# YearsSinceLastPromotion       3.0     15.0
# YearsWithCurrManager          7.0     17.0
# ProfitMargen                 78.0     96.0
# 2
# ----------------------------------------------------------------------------------------------------
# La forma del dataframe es:
# 1474 filas
# 36 columnas
# ----------------------------------------------------------------------------------------------------
# Muestra del dataframe:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 888   35.0        No     Non-Travel       1212                   Sales
# 946   40.0       Yes  Travel_Rarely        299                   Sales
# 1156  40.0        No  Travel_Rarely        884  Research & Development
# 197   42.0        No     Non-Travel        926  Research & Development
# 895   31.0        No  Travel_Rarely       1332  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 888                  8          2      Marketing              1
# 946                 25          4      Marketing              1
# 1156                15          3  Life Sciences              1
# 197                 21          2        Medical              1
# 895                 11          2        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 888             1243                        3  Female          78
# 946             1318                        4    Male          57
# 1156            1628                        1  Female          80
# 197              270                        3  Female          36
# 895             1251                        3    Male          80
#
#       JobInvolvement  JobLevel                      JobRole  JobSatisfaction  \
# 888                2         3             sales executive               4.0
# 946                2         3             sales executive               2.0
# 1156               2         3      manufacturing director               3.0
# 197                3         2      manufacturing director               3.0
# 895                3         2   healthcare representative               1.0
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 888        Married        10377.0        13755                   4      Y
# 946         Single         9094.0        17235                   2      Y
# 1156           NaN        10435.0        25800                   1      Y
# 197       Divorced         5265.0        16439                   2      Y
# 895        Married         6833.0        17089                   1      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 888       Yes                 11                  3                         2
# 946       Yes                 12                  3                         3
# 1156       No                 13                  3                         4
# 197        No                 16                  3                         2
# 895       Yes                 12                  3                         4
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 888            80.0                 1                 16
# 946            80.0                 0                  9
# 1156           80.0                 2                 18
# 197            80.0                 1                 11
# 895            80.0                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 888                     6.0                2              13
# 946                     2.0                3               5
# 1156                    2.0                3              18
# 197                     5.0                3               5
# 895                     2.0                2               6
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 888                    2                        4                  12.0
# 946                    4                        1                   NaN
# 1156                  15                       14                  12.0
# 197                    3                        0                   2.0
# 895                    5                        0                   1.0
#
#       ProfitMargen
# 888      24.558342
# 946      47.235277
# 1156     59.554264
# 197      67.972504
# 895      60.015214

# %% [markdown]
# Interpretaciones numéricas:
#
# - Attrition: De los 1474 registros, 1236 son "No". Esto indica un fuerte desbalanceo entre la rotación.
# - La columna count deberia de ser iguales en todos, detectamos presencia de Nulos (BusinessTravel,Department, EducationField, MaritalStatus, OverTime)
# - Over 18, tiene solo un valor único (como vimos anteriormente)
# - JobRole: El valor más frecuente aparece como "sALES eXECUTIVE".
# - Gender: La mayoría de la plantilla es masculina
# - Department: La gran mayoría pertenece a Research & Development
#
# Interpretaciones categóricas:
#
# - Confirmamos nulos en las columnas que no contienen 474 valores.
# - Desviación estándar en 0, columnas a eliminar, no aportan variabilidad a los datos.
# - MonthlyIncome: Hay una gran dispersión. Mientras el 50% de los empleados gana menos de 4.907, el máximo llega a 19.999.
# - Age: La media es de 37 años, con un rango que va desde los 18 hasta los 60 años.

# %% [markdown]
# Ahora ejecutamos la función para que nos devuelva los datos únicos del df

# %%
sp_fun.analisis_columnas(df_talento)
# Out:
# Columna: Age
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. nan 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1430
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 73
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: Attrition
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: BusinessTravel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel', nan]
# Length: 4, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 117
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: DailyRate
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
#   201 1427  857  933 1181 1395  662 1436  194  967 1496 1169 1145  630
#   303 1256  440 1450 1452  465  702 1157  602 1480 1268  713  134  526
#  1380  140  629 1356  328 1084  931  692 1069  313  894  556 1344  290
#   138  926 1261  472 1002  878  905 1180  121 1136  635 1151  644 1045
#   829 1242 1469  896  992 1052 1147 1396  663  119  979  319 1413  944
#  1323  532  818  854 1034  771 1401 1431  976 1411 1300  252 1327  832
#  1017 1199  504  505  916 1247  685  269 1416  833  307 1311  128  488
#   529 1210 1463  675 1385 1403  452  666 1158  228  996  728 1315  322
#  1479  797 1070  442  496 1372  920  688 1449 1117  636  506  444  950
#   889  555  230 1232  566 1302  812 1476  218 1132 1105  906  849  390
#   106 1249  192  553  117  185 1091  723 1220  588 1377 1018 1275  798
#   672 1162  508 1482  559  210  928 1001  549 1124  738  570 1130 1192
#   343  144 1296 1309  483  810  544 1062 1319  641 1332  756  845  593
#  1171  350  921 1144  143 1046  575  156 1283  755  304 1178  329 1362
#  1371  202  253  164 1107  759 1305  982  821 1381  480 1473  891 1063
#   645 1490  317  422 1485 1368 1448  296 1398 1349  986 1099 1116 1499
#   983 1009 1303 1274 1277  587  413 1276  988 1474  163  267  619  302
#   443  828  561  426  232 1306 1094  509  775  195  258  471  799  956
#   535 1495  446 1245  703  823 1246  622 1287  448  254 1365  538  525
#   558  782  362 1236 1112  204 1343  604 1216  646  160  238 1397  306
#   991  482 1176  913 1076  727  885  243  806  817 1410 1207 1442  693
#   929  562  608  580  970 1179  294  314  316  654  168  381  217  501
#   650  141  804  975 1090  346  430  268  167  621  527  883  954  310
#   719  725  715  657 1146  182  376  571  384  791 1111 1243 1092 1325
#   805  213  118  676 1252  286 1258  932 1041  859  720  946 1184  436
#   589  760  887 1318  625  180  586 1012  661  930  342 1230 1271 1278
#   607  130  300  583 1418 1269  379  395 1265 1222  341  868 1231  102
#   881 1383 1075  374 1086  781  177  500 1425 1454  617 1085  995 1122
#   618  546  462 1198 1272  154 1137 1188  188 1333  867  263  938  129
#   616  498 1404 1053  289 1376  231  152  882  903 1379  335  722  461
#   974 1126  840 1134  248  955  939 1391 1206  287 1441  109 1066  277
#   466 1055  265  135  247 1035  266  145 1038 1234 1109 1089  788  124
#   660 1186 1464  796  415  769 1003 1366  330 1492 1204  309 1330  469
#   697 1262 1050  770  406  203 1308  984  439  793 1451 1182  174  490
#   718  433  773  603  874  367  199  481  647 1384  902  819  862 1457
#   977  942 1402 1421 1361  917  200  150  179  696  116  363  107 1465
#   458 1212 1103  966 1010  326 1098  969 1167  694 1320  536  373  599
#   251  131  237 1429  648  735  531  429  968  879  640  412  848  360
#  1138  325 1322  299 1030  634  524  256 1060  935  495  282  206  943
#   523  507  601  855 1291 1405 1369  999 1202  285  404  736 1498 1200
#  1439  499  205  683 1462  949  652  332 1475  337  971 1174  667  560
#   172  383 1255  359  401  377  592 1445 1221  866  981  447 1326  748
#   990  405  115  790  830 1193 1423  467  271  410 1083  516  224  136
#  1029  333 1440  674 1342  898  824  492  598  740  888 1288  104 1108
#   479 1351  474  437  884 1370  264 1059  563  457 1313  241 1015  336
#  1387  170  208  671  711  737 1470  365  763  567  486  772  301  311
#   584  880  392  148  708 1259  786  370  678  146  581  918 1238  585
#   741  552  369  717  543  964  792  611  176  897  600 1054  428  181
#   211 1079  590  305  953  478 1375  244  511 1294  196  734 1239 1253
#  1128 1336  234  766  261 1194  431  572 1422 1297  574  355  207  706
#   280  726  414  352 1224  459 1254 1131  835 1172 1266  783  219 1213
#  1096 1251 1394  605 1064 1337  937  157  754 1168  155 1444  189  911
#  1321 1154  557  642  801  161 1382 1037  105  582  704  345 1120 1378
#   468  613 1023  628]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 588
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Department
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Sales', 'Research & Development', nan, 'Human Resources']
# Length: 4, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 29
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: DistanceFromHome
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1445
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Education
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 1 4 3 5]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: EducationField
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# [   'Life Sciences',            'Other',          'Medical',
#                 nan,        'Marketing', 'Technical Degree',
#   'Human Resources']
# Length: 7, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1467
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 58
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: EmployeeCount
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1473
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: EmployeeNumber
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [   1    2    4 ... 2064 2065 2068]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 4
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: EnvironmentSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 3 4 1]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Gender
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: HourlyRate
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 94  61  92  56  40  79  81  67  44  84  49  31  93  50  51  80  96  78
#   45  82  53  83  58  72  48  42  41  86  97  75  33  37  73  98  36  47
#   71  30  43  99  59  95  57  76  87  66  55  32  52  70  62  64  63  60
#  100  46  39  77  35  91  54  34  90  65  88  85  89  68  69  74  38]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1403
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: JobInvolvement
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [3 2 4 1]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: JobLevel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 1 3 4 5]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: JobRole
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# [          ' sales executive ',        ' research scientist ',
#      ' laboratory technician ',    ' manufacturing director ',
#  ' healthcare representative ',                   ' manager ',
#       ' sales representative ',         ' research director ',
#            ' human resources ']
# Length: 9, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1465
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: JobSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 4.  2.  3.  1. nan]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 29
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: MaritalStatus
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Single', 'Married', 'Divorced', nan, 'Marreid']
# Length: 5, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 132
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: MonthlyIncome
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [5993. 5130. 2090. ... 9991. 5390. 4404.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 137
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 14
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: MonthlyRate
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [19479 24907  2396 ...  5174 13243 10228]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 47
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: NumCompaniesWorked
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [8 1 6 9 0 4 5 2 7 3]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1464
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Over18
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Y']
# Length: 1, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1473
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: OverTime
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Yes', 'No', nan]
# Length: 3, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1471
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 44
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: PercentSalaryHike
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1459
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: PerformanceRating
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [3 4]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: RelationshipSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1 4 2 3]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: StandardHours
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [80. nan]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 164
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: StockOptionLevel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [0 1 3 2]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: TotalWorkingYears
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1434
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: TrainingTimesLastYear
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 0.  3.  2.  5.  1.  4. nan  6.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1466
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 88
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: WorkLifeBalance
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1 3 2 4]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsAtCompany
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1437
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsInCurrentRole
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1455
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsSinceLastPromotion
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1458
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsWithCurrManager
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 5.  7.  0.  2.  6. nan  8.  3. 11. 17.  4.  1. 12.  9. 10. 15. 13. 16.
#  14.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1455
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 148
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: ProfitMargen
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 69.23353355  79.40338058  12.77128548 ... -18.70892926  59.29925244
#   56.94172859]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 17
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 14
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------

# %%
df_talento.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'ProfitMargen'],
#       dtype='str')

# %% [markdown]
# Comprobamos las columnas que tienen que ver con el valor monetario

# %%
display(round(df_talento[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate']].describe().T), 2)
# Out:
#                 count     mean     std     min     25%      50%      75%  \
# DailyRate      1474.0    803.0   404.0   102.0   465.0    803.0   1157.0
# HourlyRate     1474.0     66.0    20.0    30.0    48.0     66.0     84.0
# MonthlyIncome  1460.0   6497.0  4706.0  1009.0  2909.0   4907.0   8377.0
# MonthlyRate    1474.0  14329.0  7120.0  2094.0  8054.0  14248.0  20466.0
#
#                    max
# DailyRate       1499.0
# HourlyRate       100.0
# MonthlyIncome  19999.0
# MonthlyRate    26999.0
# 2

# %%
df_talento[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'JobRole']].sample(2)
# Out:
#      DailyRate  HourlyRate  MonthlyIncome  MonthlyRate  \
# 499       1216          39         7104.0        20431
# 464        799          59         7491.0        23848
#
#                       JobRole
# 499          sales executive
# 464   manufacturing director

# %%
df_talento.groupby("JobLevel")[['DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate']].mean()
# Out:
#            DailyRate  HourlyRate  MonthlyIncome   MonthlyRate
# JobLevel
# 1         802.812500   66.740809    2784.527778  13682.580882
# 2         794.529851   65.787313    5499.277358  14812.188433
# 3         832.086758   64.164384    9816.212963  14653.420091
# 4         774.452830   65.679245   15503.783019  14538.547170
# 5         815.449275   65.724638   19181.029412  14312.057971

# %% [markdown]
# Tras analizar y no ver patrón, César nos confirma que están obsoletas y podemos borrarlas

# %%
df_limpio = df_talento.drop(columns=["DailyRate", "HourlyRate",	"MonthlyRate", "EmployeeCount", "Over18"])

# %%
df_limpio.drop(columns=['ProfitMargen'], inplace=True)

# %%
df_limpio.shape
# Out:
# (1474, 30)

# %%
df_limpio.sample()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 102  20.0       Yes  Travel_Frequently  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeNumber  \
# 102                 6          3  Life Sciences             137
#
#      EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 102                        4  Female               2         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 102   laboratory technician               4.0        Single         2926.0
#
#      NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# 102                   1      Yes                 18                  3
#
#      RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 102                         2           80.0                 0
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 102                  1                    NaN                3
#
#      YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 102               1                   0                        1
#
#      YearsWithCurrManager
# 102                   NaN

# %%
sp_fun.analisis_columnas(df_limpio)
# Out:
# Columna: Age
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. nan 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1430
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 73
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: Attrition
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: BusinessTravel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel', nan]
# Length: 4, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 117
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: Department
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Sales', 'Research & Development', nan, 'Human Resources']
# Length: 4, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 29
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: DistanceFromHome
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1445
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Education
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 1 4 3 5]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: EducationField
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# [   'Life Sciences',            'Other',          'Medical',
#                 nan,        'Marketing', 'Technical Degree',
#   'Human Resources']
# Length: 7, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1467
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 58
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: EmployeeNumber
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [   1    2    4 ... 2064 2065 2068]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 4
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: EnvironmentSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 3 4 1]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: Gender
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: JobInvolvement
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [3 2 4 1]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: JobLevel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [2 1 3 4 5]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: JobRole
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# [          ' sales executive ',        ' research scientist ',
#      ' laboratory technician ',    ' manufacturing director ',
#  ' healthcare representative ',                   ' manager ',
#       ' sales representative ',         ' research director ',
#            ' human resources ']
# Length: 9, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1465
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: JobSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 4.  2.  3.  1. nan]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 29
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: MaritalStatus
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Single', 'Married', 'Divorced', nan, 'Marreid']
# Length: 5, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1469
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 132
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: MonthlyIncome
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [5993. 5130. 2090. ... 9991. 5390. 4404.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 137
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 14
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: NumCompaniesWorked
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [8 1 6 9 0 4 5 2 7 3]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1464
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: OverTime
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: <StringArray>
# ['Yes', 'No', nan]
# Length: 3, dtype: str
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1471
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 44
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: str
#  ----------------------------------------------------------------------------------------------------
# Columna: PercentSalaryHike
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1459
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: PerformanceRating
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [3 4]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: RelationshipSatisfaction
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1 4 2 3]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: StandardHours
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [80. nan]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1472
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 164
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: StockOptionLevel
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [0 1 3 2]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: TotalWorkingYears
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1434
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: TrainingTimesLastYear
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 0.  3.  2.  5.  1.  4. nan  6.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1466
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 88
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------
# Columna: WorkLifeBalance
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [1 3 2 4]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1470
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsAtCompany
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1437
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsInCurrentRole
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1455
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsSinceLastPromotion
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1458
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 0
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: int64
#  ----------------------------------------------------------------------------------------------------
# Columna: YearsWithCurrManager
#  ----------------------------------------------------------------------------------------------------
# Valores unicos: [ 5.  7.  0.  2.  6. nan  8.  3. 11. 17.  4.  1. 12.  9. 10. 15. 13. 16.
#  14.]
#  ----------------------------------------------------------------------------------------------------
# Valores duplicados: 1455
#  ----------------------------------------------------------------------------------------------------
# Valores nulos: 148
#  ----------------------------------------------------------------------------------------------------
# El tipo de dato: float64
#  ----------------------------------------------------------------------------------------------------

# %%
df_limpio.duplicated().sum() #tenemos 4 valores duplicados.
# Out:
# np.int64(4)

# %%
duplicados = df_limpio[df_limpio.duplicated()]
print(duplicados.index)
# Out:
# RangeIndex(start=1470, stop=1474, step=1)

# %%
df_limpio.iloc[1470:1475:1]
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1470  28.0        No  Travel_Rarely                   Sales                 5
# 1471  53.0        No  Travel_Rarely  Research & Development                13
# 1472  24.0       Yes  Travel_Rarely         Human Resources                22
# 1473  45.0        No  Travel_Rarely  Research & Development                 7
#
#       Education   EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 1470          3          Medical            1469                        4
# 1471          2          Medical             250                        4
# 1472          1  Human Resources            1714                        4
# 1473          3    Life Sciences              86                        2
#
#       Gender  JobInvolvement  JobLevel                   JobRole  \
# 1470    Male               3         2          sales executive
# 1471  Female               4         2   manufacturing director
# 1472    Male               1         1          human resources
# 1473    Male               3         3       research scientist
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 1470              1.0        Single         8463.0                   0
# 1471              1.0      Divorced         4450.0                   1
# 1472              3.0       Married         1555.0                   1
# 1473              1.0      Divorced         9724.0                   2
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1470       No                 18                  3                         4
# 1471       No                 11                  3                         3
# 1472       No                 11                  3                         3
# 1473       No                 17                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 1470            NaN                 0                  6
# 1471            NaN                 2                  5
# 1472           80.0                 1                  1
# 1473            NaN                 1                 25
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 1470                    4.0                3               5
# 1471                    3.0                3               4
# 1472                    2.0                3               1
# 1473                    2.0                3               1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1470                   4                        1                   NaN
# 1471                   2                        1                   3.0
# 1472                   0                        0                   0.0
# 1473                   0                        0                   0.0

# %%
duplicadas = df_limpio.loc[df_limpio.duplicated()]
print(duplicadas)
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1470  28.0        No  Travel_Rarely                   Sales                 5
# 1471  53.0        No  Travel_Rarely  Research & Development                13
# 1472  24.0       Yes  Travel_Rarely         Human Resources                22
# 1473  45.0        No  Travel_Rarely  Research & Development                 7
#
#       Education   EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 1470          3          Medical            1469                        4
# 1471          2          Medical             250                        4
# 1472          1  Human Resources            1714                        4
# 1473          3    Life Sciences              86                        2
#
#       Gender  JobInvolvement  JobLevel                   JobRole  \
# 1470    Male               3         2          sales executive
# 1471  Female               4         2   manufacturing director
# 1472    Male               1         1          human resources
# 1473    Male               3         3       research scientist
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 1470              1.0        Single         8463.0                   0
# 1471              1.0      Divorced         4450.0                   1
# 1472              3.0       Married         1555.0                   1
# 1473              1.0      Divorced         9724.0                   2
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1470       No                 18                  3                         4
# 1471       No                 11                  3                         3
# 1472       No                 11                  3                         3
# 1473       No                 17                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 1470            NaN                 0                  6
# 1471            NaN                 2                  5
# 1472           80.0                 1                  1
# 1473            NaN                 1                 25
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 1470                    4.0                3               5
# 1471                    3.0                3               4
# 1472                    2.0                3               1
# 1473                    2.0                3               1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1470                   4                        1                   NaN
# 1471                   2                        1                   3.0
# 1472                   0                        0                   0.0
# 1473                   0                        0                   0.0

# %%
df_limpio.tail(2)
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 1472  24.0       Yes  Travel_Rarely         Human Resources                22
# 1473  45.0        No  Travel_Rarely  Research & Development                 7
#
#       Education   EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 1472          1  Human Resources            1714                        4
# 1473          3    Life Sciences              86                        2
#
#      Gender  JobInvolvement  JobLevel               JobRole  JobSatisfaction  \
# 1472   Male               1         1      human resources               3.0
# 1473   Male               3         3   research scientist               1.0
#
#      MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 1472       Married         1555.0                   1       No
# 1473      Divorced         9724.0                   2       No
#
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1472                 11                  3                         3
# 1473                 17                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 1472           80.0                 1                  1
# 1473            NaN                 1                 25
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 1472                    2.0                3               1
# 1473                    2.0                3               1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1472                   0                        0                   0.0
# 1473                   0                        0                   0.0

# %%
df_limpio.columns 
# **DailyRate** **HourlyRate** **MonthlyRate**
# **EmployeeCount**, **Over18*
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='str')

# %%
df_limpio["MaritalStatus"].unique()
# Out:
# <StringArray>
# ['Single', 'Married', 'Divorced', nan, 'Marreid']
# Length: 5, dtype: str

# %%
#vamos a cambiar el marreid por Married
df_limpio[df_limpio["MaritalStatus"] == "Marreid"] #solo hay 3 mal escritos


df_limpio['MaritalStatus'] = df_limpio['MaritalStatus'].str.replace('Marreid', 'Married')

# %%
df_limpio["MaritalStatus"].unique() #ya lo tenemos cambiado y bien
# Out:
# <StringArray>
# ['Single', 'Married', 'Divorced', nan]
# Length: 4, dtype: str

# %%
df_limpio = df_limpio.apply(lambda x: x.str.lower() if x.dtype == "str" else x) #para cambiar los nombres de las variables a minusculas

# %%
df_limpio.head(2)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       yes      travel_rarely                   sales
# 1  49.0        no  travel_frequently  research & development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  life sciences               1
# 1                 8          1  life sciences               2
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2  female               3         2
# 1                        3    male               2         2
#
#                 JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      sales executive               4.0        single         5993.0
# 1   research scientist               2.0       married         5130.0
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      yes                 11                  3
# 1                   1       no                 23                  4
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1           80.0                 0
# 1                         4            NaN                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                    0.0                1               6
# 1                 10                    3.0                3              10
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                   5.0
# 1                   7                        1                   7.0

# %%
df_limpio.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='str')

# %%
#lista y bucle con las columnas de rate que deberian ser del 1 al 4
lista = ["EnvironmentSatisfaction", "JobInvolvement", "JobSatisfaction", "PerformanceRating", "RelationshipSatisfaction" ]

# %%
for a in lista:
    print(a, df_limpio[a].unique())
# Out:
# EnvironmentSatisfaction [2 3 4 1]
# JobInvolvement [3 2 4 1]
# JobSatisfaction [ 4.  2.  3.  1. nan]
# PerformanceRating [3 4]
# RelationshipSatisfaction [1 4 2 3]

# %%
round(df_limpio.isnull().sum()/df_limpio.shape[0]*100, 2).sort_values(ascending = False).head(15)
#nuestros valores nulos en porcentajes y lo que suponen del df
# Out:
# StandardHours            11.13
# YearsWithCurrManager     10.04
# MaritalStatus             8.96
# BusinessTravel            7.94
# TrainingTimesLastYear     5.97
# Age                       4.95
# EducationField            3.93
# OverTime                  2.99
# JobSatisfaction           1.97
# Department                1.97
# MonthlyIncome             0.95
# DistanceFromHome          0.00
# Education                 0.00
# Attrition                 0.00
# JobRole                   0.00
# dtype: float64

# %%
df_limpio["StandardHours"].unique()
# Out:
# array([80., nan])

# %%
#vamos a eliminar el StandarHours ya que tiene un valor único 
df_limpio = df_limpio.drop('StandardHours', axis=1)

# %%
df_limpio.head(2)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       yes      travel_rarely                   sales
# 1  49.0        no  travel_frequently  research & development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  life sciences               1
# 1                 8          1  life sciences               2
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2  female               3         2
# 1                        3    male               2         2
#
#                 JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      sales executive               4.0        single         5993.0
# 1   research scientist               2.0       married         5130.0
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      yes                 11                  3
# 1                   1       no                 23                  4
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                    0.0                1               6                   4
# 1                    3.0                3              10                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                   5.0
# 1                        1                   7.0

# %%
df_limpio["YearsWithCurrManager"].unique()
# Out:
# array([ 5.,  7.,  0.,  2.,  6., nan,  8.,  3., 11., 17.,  4.,  1., 12.,
#         9., 10., 15., 13., 16., 14.])

# %%
df_limpio["YearsWithCurrManager"].describe()
# Out:
# count    1326.000000
# mean        4.061840
# std         3.517603
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
#como vamos a reemplazar por la media o por la mediana?
round(df_limpio.groupby("YearsWithCurrManager")[["YearsAtCompany"]].mean(), 2)
# Out:
#                       YearsAtCompany
# YearsWithCurrManager
# 0.0                             2.12
# 1.0                             5.00
# 2.0                             3.57
# 3.0                             5.20
# 4.0                             6.01
# 5.0                             8.48
# 6.0                            11.81
# 7.0                             9.89
# 8.0                            12.41
# 9.0                            14.84
# 10.0                           19.05
# 11.0                           16.41
# 12.0                           16.42
# 13.0                           21.50
# 14.0                           19.00
# 15.0                           19.50
# 16.0                           34.00
# 17.0                           19.86

# %%
round(df_limpio.groupby("YearsAtCompany")[["YearsWithCurrManager"]].agg(["mean", "median"]), 2)
# Out:
#                YearsWithCurrManager
#                                mean median
# YearsAtCompany
# 0                              0.00    0.0
# 1                              0.07    0.0
# 2                              1.75    2.0
# 3                              1.87    2.0
# 4                              2.25    2.0
# 5                              2.84    3.0
# 6                              2.97    3.0
# 7                              5.93    7.0
# 8                              5.78    7.0
# 9                              5.85    7.0
# 10                             6.63    7.0
# 11                             7.44    8.0
# 12                             8.23    8.0
# 13                             8.04    8.0
# 14                             8.94    9.0
# 15                            10.26   11.0
# 16                             9.64   10.0
# 17                             9.89    9.0
# 18                            11.18   11.0
# 19                             7.90    8.0
# 20                            10.24    9.0
# 21                             8.62    8.0
# 22                             9.62   10.0
# 23                             4.00    4.0
# 24                            10.00   10.0
# 25                             9.50    9.5
# 26                             6.33    7.0
# 27                             7.50    7.5
# 29                            10.00   10.0
# 30                            13.00   13.0
# 31                             8.00    8.0
# 32                             8.33    9.0
# 33                             7.00    9.0
# 34                            16.00   16.0
# 36                            13.00   13.0
# 37                             8.00    8.0
# 40                             6.00    6.0

# %%
# Aplicamos la función a todas las columnas usando una lista de comprensión
df_limpio.columns = [sp_fun.transformar_nombre(col) for col in df_limpio.columns]


df_limpio.head(2)
# Out:
#     age attrition    business_travel              department  \
# 0  41.0       yes      travel_rarely                   sales
# 1  49.0        no  travel_frequently  research & development
#
#    distance_from_home  education education_field  employee_number  \
# 0                   1          2   life sciences                1
# 1                   8          1   life sciences                2
#
#    environment_satisfaction  gender  job_involvement  job_level  \
# 0                         2  female                3          2
# 1                         3    male                2          2
#
#                job_role  job_satisfaction marital_status  monthly_income  \
# 0      sales executive                4.0         single          5993.0
# 1   research scientist                2.0        married          5130.0
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                       0.0                  1                 6
# 1                       3.0                  3                10
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0

# %%
media=df_limpio["years_with_curr_manager"].mean()
print(media)
# Out:
# 4.06184012066365

# %%
df_limpio["media_year"]=df_limpio["years_with_curr_manager"].fillna(media)

# %%
df_limpio.head(2)
# Out:
#     age attrition    business_travel              department  \
# 0  41.0       yes      travel_rarely                   sales
# 1  49.0        no  travel_frequently  research & development
#
#    distance_from_home  education education_field  employee_number  \
# 0                   1          2   life sciences                1
# 1                   8          1   life sciences                2
#
#    environment_satisfaction  gender  job_involvement  job_level  \
# 0                         2  female                3          2
# 1                         3    male                2          2
#
#                job_role  job_satisfaction marital_status  monthly_income  \
# 0      sales executive                4.0         single          5993.0
# 1   research scientist                2.0        married          5130.0
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                       0.0                  1                 6
# 1                       3.0                  3                10
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager  \
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0
#
#    media_year
# 0         5.0
# 1         7.0

# %%
df_limpio["mediana_year"]=df_limpio["years_with_curr_manager"].fillna(df_limpio["years_with_curr_manager"].median())

# %%
df_limpio.describe().T
# Out:
#                              count         mean          std     min      25%  \
# age                         1401.0    36.944325     9.105009    18.0    30.00
# distance_from_home          1474.0     9.199457     8.104266     1.0     2.00
# education                   1474.0     2.911126     1.024267     1.0     2.00
# employee_number             1474.0  1024.471506   602.421193     1.0   488.75
# environment_satisfaction    1474.0     2.723881     1.093280     1.0     2.00
# job_involvement             1474.0     2.729986     0.712861     1.0     2.00
# job_level                   1474.0     2.063772     1.106055     1.0     1.00
# job_satisfaction            1445.0     2.728720     1.106409     1.0     2.00
# monthly_income              1460.0  6497.448630  4706.059294  1009.0  2909.00
# num_companies_worked        1474.0     2.688602     2.496443     0.0     1.00
# percent_salary_hike         1474.0    15.206920     3.659274    11.0    12.00
# performance_rating          1474.0     3.153324     0.360422     3.0     3.00
# relationship_satisfaction   1474.0     2.713704     1.080338     1.0     2.00
# stock_option_level          1474.0     0.794437     0.851784     0.0     0.00
# total_working_years         1474.0    11.274084     7.785972     0.0     6.00
# training_times_last_year    1386.0     2.797980     1.296882     0.0     2.00
# work_life_balance           1474.0     2.761872     0.705625     1.0     2.00
# years_at_company            1474.0     6.996608     6.122920     0.0     3.00
# years_in_current_role       1474.0     4.221845     3.622032     0.0     2.00
# years_since_last_promotion  1474.0     2.183175     3.219356     0.0     0.00
# years_with_curr_manager     1326.0     4.061840     3.517603     0.0     2.00
# media_year                  1474.0     4.061840     3.336210     0.0     2.00
# mediana_year                1474.0     3.955224     3.351449     0.0     2.00
#
#                                50%      75%      max
# age                           36.0    43.00     60.0
# distance_from_home             7.0    14.00     29.0
# education                      3.0     4.00      5.0
# employee_number             1020.5  1555.75   2068.0
# environment_satisfaction       3.0     4.00      4.0
# job_involvement                3.0     3.00      4.0
# job_level                      2.0     3.00      5.0
# job_satisfaction               3.0     4.00      4.0
# monthly_income              4907.0  8377.00  19999.0
# num_companies_worked           2.0     4.00      9.0
# percent_salary_hike           14.0    18.00     25.0
# performance_rating             3.0     3.00      4.0
# relationship_satisfaction      3.0     4.00      4.0
# stock_option_level             1.0     1.00      3.0
# total_working_years           10.0    15.00     40.0
# training_times_last_year       3.0     3.00      6.0
# work_life_balance              3.0     3.00      4.0
# years_at_company               5.0     9.00     40.0
# years_in_current_role          3.0     7.00     18.0
# years_since_last_promotion     1.0     3.00     15.0
# years_with_curr_manager        3.0     7.00     17.0
# media_year                     3.0     7.00     17.0
# mediana_year                   3.0     7.00     17.0

# %%
df_limpio.shape #Vemos que efectivamente se han rellenado los nulos.
# hemos concluido que nos quedamos con la mediana ya que no vemos cambios significativos y no tiene valores decimales(más apropiado para los años)
# Out:
# (1474, 31)

# %%
df_limpio[["marital_status"]].describe().T
# Out:
#                count unique      top freq
# marital_status  1342      3  married  607

# %%
df_limpio["marital_status"].value_counts(dropna=False).reset_index()
# Out:
#   marital_status  count
# 0        married    607
# 1         single    437
# 2       divorced    298
# 3            NaN    132

# %%
round(df_limpio["marital_status"].value_counts(dropna=False)/(df_limpio.shape[0])*100,2).reset_index()
# Out:
#   marital_status  count
# 0        married  41.18
# 1         single  29.65
# 2       divorced  20.22
# 3            NaN   8.96

# %%
#Categorizarlo como desconocido y comprobar si encaja con el patron de : married, single o divorced.

# %%
df_limpio["marital_status"]=df_limpio["marital_status"].fillna("unknown")

# %%
round(df_limpio["marital_status"].value_counts(dropna=False)/(df_limpio.shape[0])*100,2).reset_index()
# Out:
#   marital_status  count
# 0        married  41.18
# 1         single  29.65
# 2       divorced  20.22
# 3        unknown   8.96

# %%
sns.barplot(data=df_limpio,x="marital_status",y="age");

# %%
#no hemos encontrado ningún patron claro en cuanto al grupo que puede pertenecer el uknown por lo tanto lo dejamos asi

# %% [markdown]
# Vamos a comprobar si hay algun patron con las horas extras y el estado civil

# %%
sns.countplot(data=df_limpio,x="marital_status",hue="over_time");

# %% [markdown]
# Vamos a comprobar si hay algun patron con los viajes de negocios y el estado civil

# %%
sns.countplot(data=df_limpio,x="marital_status",hue="business_travel");

# %%
df_limpio["business_travel"].value_counts(dropna=False)/df_limpio.shape[0]*100
# Out:
# business_travel
# travel_rarely        64.789688
# travel_frequently    17.842605
# non-travel            9.430122
# NaN                   7.937585
# Name: count, dtype: float64

# %%
df_limpio["business_travel"]= df_limpio["business_travel"].fillna("unknown")
df_limpio["business_travel"].value_counts()
# Out:
# business_travel
# travel_rarely        955
# travel_frequently    263
# non-travel           139
# unknown              117
# Name: count, dtype: int64

# %%
sns.boxplot(data=df_limpio,x="monthly_income",y="business_travel");

# %%
sns.boxplot(data=df_limpio,y="work_life_balance", x="business_travel");

# %%
df_limpio.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'job_involvement', 'job_level',
#        'job_role', 'job_satisfaction', 'marital_status', 'monthly_income',
#        'num_companies_worked', 'over_time', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager', 'media_year',
#        'mediana_year'],
#       dtype='str')

# %%
sns.boxplot(data=df_limpio,y="job_level", x="business_travel");

# %%
sns.countplot(data=df_limpio,x="business_travel");

# %%
df_limpio["business_travel"]= df_limpio["business_travel"].str.replace("unknown","non-travel")
df_limpio["business_travel"].value_counts()
# Out:
# business_travel
# travel_rarely        955
# travel_frequently    263
# non-travel           256
# Name: count, dtype: int64

# %%
df_limpio["business_travel"].unique()
# Out:
# <StringArray>
# ['travel_rarely', 'travel_frequently', 'non-travel']
# Length: 3, dtype: str

# %%
round(df_limpio.isnull().sum()/df_limpio.shape[0]*100, 2).sort_values(ascending = False).head(10)
# Out:
# years_with_curr_manager     10.04
# training_times_last_year     5.97
# age                          4.95
# education_field              3.93
# over_time                    2.99
# job_satisfaction             1.97
# department                   1.97
# monthly_income               0.95
# employee_number              0.00
# gender                       0.00
# dtype: float64

# %%
df_limpio.head(2)
# Out:
#   attrition    business_travel              department  distance_from_home  \
# 0       yes      travel_rarely                   sales                   1
# 1        no  travel_frequently  research & development                   8
#
#    education education_field  employee_number  environment_satisfaction  \
# 0          2   life sciences                1                         2
# 1          1   life sciences                2                         3
#
#    gender  job_involvement  job_level              job_role marital_status  \
# 0  female                3          2      sales executive          single
# 1    male                2          2   research scientist         married
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                         0                  1                 6
# 1                         3                  3                10
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager  \
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0
#
#    age  job_satisfaction  monthly_income
# 0   41                 4          5993.0
# 1   49                 2          5130.0

# %% [markdown]
# Nos quedamos con la mediana, asi que borramos las creadas de forma auxiliar y renombramos la final

# %%
df_limpio.drop(columns=["years_with_curr_manager", "media_year"], inplace=True)

# %%
df_limpio.sample()
# Out:
#      age attrition business_travel department  distance_from_home  education  \
# 98  58.0        no   travel_rarely        NaN                  10          4
#
#    education_field  employee_number  environment_satisfaction gender  \
# 98         medical              131                         4   male
#
#     job_involvement  job_level           job_role  job_satisfaction  \
# 98                3          4   sales executive                3.0
#
#    marital_status  monthly_income  num_companies_worked over_time  \
# 98         single         13872.0                     0        no
#
#     percent_salary_hike  performance_rating  relationship_satisfaction  \
# 98                   13                   3                          3
#
#     stock_option_level  total_working_years  training_times_last_year  \
# 98                   0                   38                       1.0
#
#     work_life_balance  years_at_company  years_in_current_role  \
# 98                  2                37                     10
#
#     years_since_last_promotion  mediana_year
# 98                           1           8.0

# %%
df_limpio.rename(columns= {"mediana_year": "years_with_curr_manager"}, inplace=True)

# %%
df_limpio.sample()
# Out:
#      age attrition business_travel              department  \
# 680  NaN        no   travel_rarely  research & development
#
#      distance_from_home  education education_field  employee_number  \
# 680                   7          4           other              949
#
#      environment_satisfaction gender  job_involvement  job_level  \
# 680                         2   male                3          1
#
#                  job_role  job_satisfaction marital_status  monthly_income  \
# 680   research scientist                4.0         single          4678.0
#
#      num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 680                     2        no                   18                   3
#
#      relationship_satisfaction  stock_option_level  total_working_years  \
# 680                          3                   0                    8
#
#      training_times_last_year  work_life_balance  years_at_company  \
# 680                       6.0                  3                 6
#
#      years_in_current_role  years_since_last_promotion  \
# 680                      2                           0
#
#      years_with_curr_manager
# 680                      1.0

# %%
df_limpio["education_field"].describe()
# Out:
# count              1416
# unique                6
# top       life sciences
# freq                582
# Name: education_field, dtype: object

# %%
df_limpio["education_field"].unique()
# Out:
# <StringArray>
# [   'life sciences',            'other',          'medical',
#                 nan,        'marketing', 'technical degree',
#   'human resources']
# Length: 7, dtype: str

# %%
round(df_limpio["education_field"].value_counts(dropna=False)/(df_limpio.shape[0])*100,2).reset_index()
# Out:
#     education_field  count
# 0     life sciences  39.48
# 1           medical  30.46
# 2         marketing  10.31
# 3  technical degree   8.82
# 4             other   5.36
# 5               NaN   3.93
# 6   human resources   1.63

# %%
sns.histplot(
    data=df_limpio.assign(
        education_field=df_limpio["education_field"].fillna("Nulos")
    ),
    x="education_field",
    color="lightgreen"
)

plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df_limpio.assign(
        education_field=df_limpio["education_field"].fillna("Nulos")), x= "education", y="education_field");

# %%
sns.barplot(data=df_limpio.assign(
        education_field=df_limpio["education_field"].fillna("Nulos")),errorbar=None, x= "education_field", y= "education")
plt.xticks(rotation= 90);

# %%
sns.countplot(data=df_limpio.assign(
        education_field=df_limpio["education_field"].fillna("Nulos")), x= "education_field", hue= "department")
plt.xticks(rotation= 90);

# %%
df_limpio["education_field"]= df_limpio["education_field"].fillna("other")
df_limpio["education_field"].value_counts(dropna=False)
# Out:
# education_field
# life sciences       582
# medical             449
# marketing           152
# other               137
# technical degree    130
# human resources      24
# Name: count, dtype: int64

# %%
round(df_limpio.isna().sum().sort_values(ascending=False)/df_limpio.shape[0]*100).head(8), 2
# Out:
# (training_times_last_year    6.0
#  age                         5.0
#  over_time                   3.0
#  department                  2.0
#  job_satisfaction            2.0
#  monthly_income              1.0
#  education_field             0.0
#  employee_number             0.0
#  dtype: float64,
#  2)

# %%
df_limpio["training_times_last_year"].value_counts(dropna=False)
# Out:
# training_times_last_year
# 2.0    520
# 3.0    456
# 4.0    118
# 5.0    111
# NaN     88
# 1.0     65
# 6.0     63
# 0.0     53
# Name: count, dtype: int64

# %%
#Vamos a rellenar los nulos de la columna training_times_last_year por los valores 0.0
# 
df_limpio["training_times_last_year"]= df_limpio["training_times_last_year"].fillna(0.0)
df_limpio["training_times_last_year"].value_counts(dropna=False)
# Out:
# training_times_last_year
# 2.0    520
# 3.0    456
# 0.0    141
# 4.0    118
# 5.0    111
# 1.0     65
# 6.0     63
# Name: count, dtype: int64

# %%
df_limpio["age"].value_counts(dropna=False)
# Out:
# age
# 35.0    73
# NaN     73
# 34.0    72
# 36.0    68
# 29.0    65
# 31.0    63
# 32.0    59
# 33.0    57
# 30.0    57
# 40.0    56
# 38.0    54
# 37.0    50
# 27.0    48
# 28.0    46
# 42.0    41
# 39.0    41
# 45.0    41
# 41.0    39
# 26.0    36
# 44.0    32
# 46.0    32
# 43.0    30
# 50.0    27
# 24.0    24
# 47.0    24
# 25.0    23
# 49.0    22
# 55.0    21
# 53.0    19
# 48.0    18
# 51.0    18
# 52.0    17
# 22.0    16
# 54.0    16
# 56.0    14
# 23.0    13
# 58.0    13
# 21.0    11
# 20.0    11
# 59.0     9
# 19.0     8
# 18.0     8
# 60.0     5
# 57.0     4
# Name: count, dtype: int64

# %%
#Aqui renombramos los nulos de edad por "99"df_limpio

#df_limpio["age"]= df_limpio["age"].fillna(99)

# %%
sns.scatterplot(data=df_limpio,y="age",x="years_at_company", hue="attrition");

# %%
sns.countplot(data=df_limpio,hue="attrition",x="years_at_company");

# %%
df_limpio.head(2)
# Out:
#     age attrition    business_travel              department  \
# 0  41.0       yes      travel_rarely                   sales
# 1  49.0        no  travel_frequently  research & development
#
#    distance_from_home  education education_field  employee_number  \
# 0                   1          2   life sciences                1
# 1                   8          1   life sciences                2
#
#    environment_satisfaction  gender  job_involvement  job_level  \
# 0                         2  female                3          2
# 1                         3    male                2          2
#
#                job_role  job_satisfaction marital_status  monthly_income  \
# 0      sales executive                4.0         single          5993.0
# 1   research scientist                2.0        married          5130.0
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                       0.0                  1                 6
# 1                       3.0                  3                10
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0

# %% [markdown]
# Decidimos imputar los nulos de edad usando el knn

# %%
imputer = KNNImputer(n_neighbors=5)  # Imputar utilizando 5 vecinos más cercanos
df_limpio["age_knn"] = imputer.fit_transform(df_limpio[["age", "monthly_income", "years_at_company"]])[:,0]

# %%
df_limpio.sample()
# Out:
#        age attrition business_travel department  distance_from_home  \
# 1220  36.0        no   travel_rarely      sales                   2
#
#       education education_field  employee_number  environment_satisfaction  \
# 1220          4   life sciences             1710                         3
#
#       gender  job_involvement  job_level                job_role  \
# 1220  female                3          2   sales representative
#
#       job_satisfaction marital_status  monthly_income  num_companies_worked  \
# 1220               4.0         single          4502.0                     3
#
#      over_time  percent_salary_hike  performance_rating  \
# 1220        no                   15                   3
#
#       relationship_satisfaction  stock_option_level  total_working_years  \
# 1220                          3                   0                   17
#
#       training_times_last_year  work_life_balance  years_at_company  \
# 1220                       2.0                  2                13
#
#       years_in_current_role  years_since_last_promotion  \
# 1220                      7                           6
#
#       years_with_curr_manager  age_knn
# 1220                      7.0     36.0

# %%
df_limpio[["age", "age_knn"]].describe(include=np.number).T
# Out:
#           count       mean       std   min   25%   50%   75%   max
# age      1401.0  36.944325  9.105009  18.0  30.0  36.0  43.0  60.0
# age_knn  1474.0  36.960380  8.897201  18.0  31.0  36.0  42.0  60.0

# %% [markdown]
# Tras comprobar que mantiene integridad y coherencia, borramos la inicial y renombramos la final

# %%
df_limpio.drop(columns="age", inplace=True)

# %%
df_limpio.rename(columns= {"age_knn": "age"}, inplace=True)

# %%
df_limpio.sample()
# Out:
#     attrition business_travel department  distance_from_home  education  \
# 507        no      non-travel      sales                   3          2
#
#     education_field  employee_number  environment_satisfaction  gender  \
# 507         medical              690                         2  female
#
#      job_involvement  job_level           job_role  job_satisfaction  \
# 507                3          2   sales executive                3.0
#
#     marital_status  monthly_income  num_companies_worked over_time  \
# 507        married          5561.0                     1        no
#
#      percent_salary_hike  performance_rating  relationship_satisfaction  \
# 507                   14                   3                          1
#
#      stock_option_level  total_working_years  training_times_last_year  \
# 507                   1                    6                       5.0
#
#      work_life_balance  years_at_company  years_in_current_role  \
# 507                  2                 6                      0
#
#      years_since_last_promotion  years_with_curr_manager   age
# 507                           1                      2.0  29.0

# %%
df_limpio["over_time"] = df_limpio["over_time"].fillna("no")

# %%
df_limpio.isna().sum().sort_values(ascending=False).head(5)
# Out:
# department            29
# job_satisfaction      29
# monthly_income        14
# distance_from_home     0
# attrition              0
# dtype: int64

# %%
round(df_limpio.isnull().sum()/df_limpio.shape[0]*100, 2).sort_values(ascending = False).head(5)
# Out:
# department            1.97
# job_satisfaction      1.97
# monthly_income        0.95
# distance_from_home    0.00
# attrition             0.00
# dtype: float64

# %%
sns.scatterplot(data=df_limpio.assign(
        department=df_limpio["department"].fillna("Nulos")
    ), x="department", y="job_role")
# Out:
# <Axes: xlabel='department', ylabel='job_role'>

# %%
df_limpio["department"] = df_limpio["department"].fillna("unknown")

# %%
df_limpio.head(1)
# Out:
#   attrition business_travel department  distance_from_home  education  \
# 0       yes   travel_rarely      sales                   1          2
#
#   education_field  employee_number  environment_satisfaction  gender  \
# 0   life sciences                1                         2  female
#
#    job_involvement  job_level           job_role  job_satisfaction  \
# 0                3          2   sales executive                4.0
#
#   marital_status  monthly_income  num_companies_worked over_time  \
# 0         single          5993.0                     8       yes
#
#    percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                   11                   3                          1
#
#    stock_option_level  total_working_years  training_times_last_year  \
# 0                   0                    8                       0.0
#
#    work_life_balance  years_at_company  years_in_current_role  \
# 0                  1                 6                      4
#
#    years_since_last_promotion  years_with_curr_manager   age
# 0                           0                      5.0  41.0

# %%
imputer = KNNImputer(n_neighbors=5)  # Imputar utilizando 5 vecinos más cercanos
df_limpio["satisfaction_knn"] = imputer.fit_transform(df_limpio[["job_satisfaction","environment_satisfaction", "relationship_satisfaction"]])[:,0]

# %%
df_limpio.sample()
# Out:
#      attrition business_travel              department  distance_from_home  \
# 1402        no   travel_rarely  research & development                   2
#
#       education education_field  employee_number  environment_satisfaction  \
# 1402          1         medical             1974                         4
#
#       gender  job_involvement  job_level                 job_role  \
# 1402  female                1          1   laboratory technician
#
#       job_satisfaction marital_status  monthly_income  num_companies_worked  \
# 1402               4.0        unknown          1129.0                     1
#
#      over_time  percent_salary_hike  performance_rating  \
# 1402       yes                   11                   3
#
#       relationship_satisfaction  stock_option_level  total_working_years  \
# 1402                          3                   3                    1
#
#       training_times_last_year  work_life_balance  years_at_company  \
# 1402                       4.0                  3                 1
#
#       years_in_current_role  years_since_last_promotion  \
# 1402                      0                           0
#
#       years_with_curr_manager   age  satisfaction_knn
# 1402                      0.0  31.0               4.0

# %%
df_limpio[["job_satisfaction", "satisfaction_knn"]].describe().T
# Out:
#                    count      mean       std  min  25%  50%  75%  max
# job_satisfaction  1445.0  2.728720  1.106409  1.0  2.0  3.0  4.0  4.0
# satisfaction_knn  1474.0  2.730393  1.096392  1.0  2.0  3.0  4.0  4.0

# %%
df_limpio.drop(columns="job_satisfaction", inplace=True)

# %%
df_limpio.rename(columns={"satisfaction_knn": "job_satisfaction"}, inplace=True)

# %%
df_limpio.head()
# Out:
#   attrition    business_travel              department  distance_from_home  \
# 0       yes      travel_rarely                   sales                   1
# 1        no  travel_frequently  research & development                   8
# 2       yes      travel_rarely  research & development                   2
# 3        no  travel_frequently  research & development                   3
# 4        no      travel_rarely  research & development                   2
#
#    education education_field  employee_number  environment_satisfaction  \
# 0          2   life sciences                1                         2
# 1          1   life sciences                2                         3
# 2          2           other                4                         4
# 3          4   life sciences                5                         4
# 4          1         medical                7                         1
#
#    gender  job_involvement  job_level                 job_role marital_status  \
# 0  female                3          2         sales executive          single
# 1    male                2          2      research scientist         married
# 2    male                2          1   laboratory technician          single
# 3  female                3          1      research scientist         married
# 4    male                3          1   laboratory technician         married
#
#    monthly_income  num_companies_worked over_time  percent_salary_hike  \
# 0          5993.0                     8       yes                   11
# 1          5130.0                     1        no                   23
# 2          2090.0                     6       yes                   15
# 3          2909.0                     1       yes                   11
# 4          3468.0                     9        no                   12
#
#    performance_rating  relationship_satisfaction  stock_option_level  \
# 0                   3                          1                   0
# 1                   4                          4                   1
# 2                   3                          2                   0
# 3                   3                          3                   0
# 4                   3                          4                   1
#
#    total_working_years  training_times_last_year  work_life_balance  \
# 0                    8                       0.0                  1
# 1                   10                       3.0                  3
# 2                    7                       3.0                  3
# 3                    8                       3.0                  3
# 4                    6                       3.0                  3
#
#    years_at_company  years_in_current_role  years_since_last_promotion  \
# 0                 6                      4                           0
# 1                10                      7                           1
# 2                 0                      0                           0
# 3                 8                      7                           3
# 4                 2                      2                           2
#
#    years_with_curr_manager   age  job_satisfaction
# 0                      5.0  41.0               4.0
# 1                      7.0  49.0               2.0
# 2                      0.0  37.0               3.0
# 3                      0.0  33.0               3.0
# 4                      2.0  27.0               2.0

# %%
df_limpio.isna().sum().sort_values(ascending=False)
# Out:
# monthly_income                14
# business_travel                0
# department                     0
# distance_from_home             0
# attrition                      0
# education_field                0
# employee_number                0
# environment_satisfaction       0
# gender                         0
# job_involvement                0
# job_level                      0
# job_role                       0
# education                      0
# marital_status                 0
# num_companies_worked           0
# over_time                      0
# percent_salary_hike            0
# performance_rating             0
# relationship_satisfaction      0
# stock_option_level             0
# total_working_years            0
# training_times_last_year       0
# work_life_balance              0
# years_at_company               0
# years_in_current_role          0
# years_since_last_promotion     0
# years_with_curr_manager        0
# age                            0
# job_satisfaction               0
# dtype: int64

# %%
sns.scatterplot(data=df_limpio, x="monthly_income", y="job_level");

# %%
imputer = KNNImputer(n_neighbors=5)  # Imputar utilizando 5 vecinos más cercanos
df_limpio["monthly_knn"] = imputer.fit_transform(df_limpio[["monthly_income","job_level", "education"]])[:,0]

# %%
df_limpio[["monthly_knn", "monthly_income"]].describe().T
# Out:
#                  count         mean          std     min     25%     50%  \
# monthly_knn     1474.0  6500.079376  4702.432869  1009.0  2909.5  4936.0
# monthly_income  1460.0  6497.448630  4706.059294  1009.0  2909.0  4907.0
#
#                    75%      max
# monthly_knn     8379.0  19999.0
# monthly_income  8377.0  19999.0

# %%
df_limpio.drop(columns="monthly_income", inplace=True)

# %%
df_limpio.rename(columns={"monthly_knn": "monthly_income"}, inplace=True)

# %%
df_limpio.isna().sum()
# Out:
# attrition                     0
# business_travel               0
# department                    0
# distance_from_home            0
# education                     0
# education_field               0
# employee_number               0
# environment_satisfaction      0
# gender                        0
# job_involvement               0
# job_level                     0
# job_role                      0
# marital_status                0
# num_companies_worked          0
# over_time                     0
# percent_salary_hike           0
# performance_rating            0
# relationship_satisfaction     0
# stock_option_level            0
# total_working_years           0
# training_times_last_year      0
# work_life_balance             0
# years_at_company              0
# years_in_current_role         0
# years_since_last_promotion    0
# years_with_curr_manager       0
# age                           0
# job_satisfaction              0
# monthly_income                0
# dtype: int64

# %%
df_limpio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   attrition                   1474 non-null   str
#  1   business_travel             1474 non-null   str
#  2   department                  1474 non-null   str
#  3   distance_from_home          1474 non-null   int64
#  4   education                   1474 non-null   int64
#  5   education_field             1474 non-null   str
#  6   employee_number             1474 non-null   int64
#  7   environment_satisfaction    1474 non-null   int64
#  8   gender                      1474 non-null   str
#  9   job_involvement             1474 non-null   int64
#  10  job_level                   1474 non-null   int64
#  11  job_role                    1474 non-null   str
#  12  marital_status              1474 non-null   str
#  13  num_companies_worked        1474 non-null   int64
#  14  over_time                   1474 non-null   str
#  15  percent_salary_hike         1474 non-null   int64
#  16  performance_rating          1474 non-null   int64
#  17  relationship_satisfaction   1474 non-null   int64
#  18  stock_option_level          1474 non-null   int64
#  19  total_working_years         1474 non-null   int64
#  20  training_times_last_year    1474 non-null   float64
#  21  work_life_balance           1474 non-null   int64
#  22  years_at_company            1474 non-null   int64
#  23  years_in_current_role       1474 non-null   int64
#  24  years_since_last_promotion  1474 non-null   int64
#  25  years_with_curr_manager     1474 non-null   float64
#  26  age                         1474 non-null   float64
#  27  job_satisfaction            1474 non-null   float64
#  28  monthly_income              1474 non-null   float64
# dtypes: float64(5), int64(16), str(8)
# memory usage: 334.1 KB

# %%
df_limpio.head(2)
# Out:
#   attrition    business_travel              department  distance_from_home  \
# 0       yes      travel_rarely                   sales                   1
# 1        no  travel_frequently  research & development                   8
#
#    education education_field  employee_number  environment_satisfaction  \
# 0          2   life sciences                1                         2
# 1          1   life sciences                2                         3
#
#    gender  job_involvement  job_level              job_role marital_status  \
# 0  female                3          2      sales executive          single
# 1    male                2          2   research scientist         married
#
#    num_companies_worked over_time  percent_salary_hike  performance_rating  \
# 0                     8       yes                   11                   3
# 1                     1        no                   23                   4
#
#    relationship_satisfaction  stock_option_level  total_working_years  \
# 0                          1                   0                    8
# 1                          4                   1                   10
#
#    training_times_last_year  work_life_balance  years_at_company  \
# 0                         0                  1                 6
# 1                         3                  3                10
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager  \
# 0                      4                           0                      5.0
# 1                      7                           1                      7.0
#
#    age  job_satisfaction  monthly_income
# 0   41                 4          5993.0
# 1   49                 2          5130.0

# %%
cambiar_int = ["training_times_last_year", "age",  "job_satisfaction"]

# %%
for col in cambiar_int:
    df_limpio[col] = df_limpio[col].astype(int)

# %%
df_limpio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   attrition                   1474 non-null   str
#  1   business_travel             1474 non-null   str
#  2   department                  1474 non-null   str
#  3   distance_from_home          1474 non-null   int64
#  4   education                   1474 non-null   int64
#  5   education_field             1474 non-null   str
#  6   employee_number             1474 non-null   int64
#  7   environment_satisfaction    1474 non-null   int64
#  8   gender                      1474 non-null   str
#  9   job_involvement             1474 non-null   int64
#  10  job_level                   1474 non-null   int64
#  11  job_role                    1474 non-null   str
#  12  marital_status              1474 non-null   str
#  13  num_companies_worked        1474 non-null   int64
#  14  over_time                   1474 non-null   str
#  15  percent_salary_hike         1474 non-null   int64
#  16  performance_rating          1474 non-null   int64
#  17  relationship_satisfaction   1474 non-null   int64
#  18  stock_option_level          1474 non-null   int64
#  19  total_working_years         1474 non-null   int64
#  20  training_times_last_year    1474 non-null   int64
#  21  work_life_balance           1474 non-null   int64
#  22  years_at_company            1474 non-null   int64
#  23  years_in_current_role       1474 non-null   int64
#  24  years_since_last_promotion  1474 non-null   int64
#  25  years_with_curr_manager     1474 non-null   float64
#  26  age                         1474 non-null   int64
#  27  job_satisfaction            1474 non-null   int64
#  28  monthly_income              1474 non-null   float64
# dtypes: float64(2), int64(19), str(8)
# memory usage: 334.1 KB

# %% [markdown]
# Guardamos el df_limpio para sacar los insights relevantes.

# %%
df_limpio.to_csv("files/hr_final.csv")
